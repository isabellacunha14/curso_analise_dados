# %% [markdown]
# # Uso da Biblioteca Pandas

# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd

# %%
dados = pd.read_excel('/content/drive/MyDrive/Curso Analise de Dados/planilha_modulo2.xlsx')

# %%
dados
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 0     zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1     zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2     zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3     zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
# ...                                ...    ...         ...        ...
# 4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29  Masculino
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34   Feminino
# 4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29  Masculino
# 4269  00xu7yujd7s57emj00xu7y0c3njix3de    NaN       17-21  Masculino
# 4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0             Parda  Não  Não acredito que minha experiência profissiona...
# 1             Parda  Não  Sim, acredito que a minha a experiência profis...
# 2            Branca  Não                                                NaN
# 3            Branca  Não                                                NaN
# 4            Branca  Não  Não acredito que minha experiência profissiona...
# ...             ...  ...                                                ...
# 4266         Branca  Não                                                NaN
# 4267         Branca  Não  Não acredito que minha experiência profissiona...
# 4268         Branca  Não                                                NaN
# 4269         Branca  Não                                                NaN
# 4270         Branca  Não                                                NaN
#
#       PREJUDICA                         ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 0         False                                           NaN            True
# 1          True  Aprovação em processos seletivos/entrevistas            True
# 2         False                                           NaN            True
# 3         False                                           NaN            True
# 4         False                                           NaN            True
# ...         ...                                           ...             ...
# 4266      False                                           NaN            True
# 4267      False                                           NaN            True
# 4268      False                                           NaN            True
# 4269      False                                           NaN            True
# 4270      False                                           NaN            True
#
#       ... NUMERO DE FUNCIONARIOS GESTOR?   NIVEL NOVO NIVEL  \
# 0     ...         Acima de 3.000   False  Júnior     Júnior
# 1     ...         Acima de 3.000    True     NaN     GESTOR
# 2     ...         Acima de 3.000   False   Pleno      Pleno
# 3     ...         Acima de 3.000   False  Sênior     Sênior
# 4     ...           de 101 a 500   False   Pleno      Pleno
# ...   ...                    ...     ...     ...        ...
# 4266  ...         Acima de 3.000   False   Pleno      Pleno
# 4267  ...            de 51 a 100   False   Pleno      Pleno
# 4268  ...           de 101 a 500    True     NaN     GESTOR
# 4269  ...       de 1.001 a 3.000   False  Júnior     Júnior
# 4270  ...         de 501 a 1.000   False  Júnior     Júnior
#
#            CARGO COMO GESTOR  \
# 0                        NaN
# 1     Supervisor/Coordenador
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 4266                     NaN
# 4267                     NaN
# 4268            Gerente/Head
# 4269                     NaN
# 4270                     NaN
#
#                                             CARGO ATUAL  \
# 0                   DBA/Administrador de Banco de Dados
# 1                                                   NaN
# 2     Desenvolvedor/ Engenheiro de Software/ Analist...
# 3                     Cientista de Dados/Data Scientist
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...
# ...                                                 ...
# 4266                     Analista de Dados/Data Analyst
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...
# 4268                                                NaN
# 4269                                        Outra Opção
# 4270                     Analista de Dados/Data Analyst
#
#                         FAIXA SALARIAL  \
# 0      de R$ 8.001/mês a R$ 12.000/mês
# 1       de R$ 4.001/mês a R$ 6.000/mês
# 2     de R$ 12.001/mês a R$ 16.000/mês
# 3     de R$ 12.001/mês a R$ 16.000/mês
# 4       de R$ 6.001/mês a R$ 8.000/mês
# ...                                ...
# 4266    de R$ 4.001/mês a R$ 6.000/mês
# 4267    de R$ 3.001/mês a R$ 4.000/mês
# 4268  de R$ 16.001/mês a R$ 20.000/mês
# 4269             Menos de R$ 1.000/mês
# 4270    de R$ 3.001/mês a R$ 4.000/mês
#
#       QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 0                                         de 1 a 2 anos
# 1                                         de 3 a 4 anos
# 2                                         de 3 a 4 anos
# 3                                         de 4 a 6 anos
# 4                Não tenho experiência na área de dados
# ...                                                 ...
# 4266                                      de 3 a 4 anos
# 4267                                      de 1 a 2 anos
# 4268                                      de 4 a 6 anos
# 4269                                     Menos de 1 ano
# 4270                                      de 1 a 2 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 0                                        de 7 a 10 anos
# 1                                        Menos de 1 ano
# 2                                       Mais de 10 anos
# 3     Não tive experiência na área de TI/Engenharia ...
# 4                                       Mais de 10 anos
# ...                                                 ...
# 4266                                     de 7 a 10 anos
# 4267  Não tive experiência na área de TI/Engenharia ...
# 4268  Não tive experiência na área de TI/Engenharia ...
# 4269  Não tive experiência na área de TI/Engenharia ...
# 4270  Não tive experiência na área de TI/Engenharia ...
#
#       SALARIO
# 0     10000.0
# 1      5000.0
# 2     14000.0
# 3     14000.0
# 4      7000.0
# ...       ...
# 4266   5000.0
# 4267   3500.0
# 4268  18000.0
# 4269   1000.0
# 4270   3500.0
#
# [4271 rows x 30 columns]

# %%
# primeiras linha da tabela, padrao ser as 5 primeiras
dados.head(10)
# Out:
#                                  ID  IDADE FAIXA IDADE     GENERO  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
# 5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34   Feminino
# 6  zytlxsdgalh22cgrijvzytlxa49i8yzx   21.0       17-21  Masculino
# 7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34   Feminino
# 8  zy4o5dk6iuxpdwgzy4o58xvd6ykwohrj   33.0       30-34  Masculino
# 9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
# 5          Parda  Não  Não acredito que minha experiência profissiona...
# 6          Parda  Não  Não acredito que minha experiência profissiona...
# 7         Branca  Não  Não acredito que minha experiência profissiona...
# 8         Branca  Não                                                NaN
# 9          Parda  Não  Não acredito que minha experiência profissiona...
#
#    PREJUDICA                         ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 0      False                                           NaN            True
# 1       True  Aprovação em processos seletivos/entrevistas            True
# 2      False                                           NaN            True
# 3      False                                           NaN            True
# 4      False                                           NaN            True
# 5      False                                           NaN            True
# 6      False                                           NaN            True
# 7      False                                           NaN            True
# 8      False                                           NaN            True
# 9      False                                           NaN            True
#
#    ... NUMERO DE FUNCIONARIOS GESTOR?   NIVEL NOVO NIVEL  \
# 0  ...         Acima de 3.000   False  Júnior     Júnior
# 1  ...         Acima de 3.000    True     NaN     GESTOR
# 2  ...         Acima de 3.000   False   Pleno      Pleno
# 3  ...         Acima de 3.000   False  Sênior     Sênior
# 4  ...           de 101 a 500   False   Pleno      Pleno
# 5  ...         Acima de 3.000   False   Pleno      Pleno
# 6  ...         Acima de 3.000   False  Júnior     Júnior
# 7  ...              de 6 a 10   False  Júnior     Júnior
# 8  ...         Acima de 3.000   False  Sênior     Sênior
# 9  ...         Acima de 3.000   False   Pleno      Pleno
#
#         CARGO COMO GESTOR                                        CARGO ATUAL  \
# 0                     NaN                DBA/Administrador de Banco de Dados
# 1  Supervisor/Coordenador                                                NaN
# 2                     NaN  Desenvolvedor/ Engenheiro de Software/ Analist...
# 3                     NaN                  Cientista de Dados/Data Scientist
# 4                     NaN  Desenvolvedor/ Engenheiro de Software/ Analist...
# 5                     NaN                                          Professor
# 6                     NaN                          Analista de BI/BI Analyst
# 7                     NaN  Desenvolvedor/ Engenheiro de Software/ Analist...
# 8                     NaN                          Analista de BI/BI Analyst
# 9                     NaN                                          Professor
#
#                      FAIXA SALARIAL  \
# 0   de R$ 8.001/mês a R$ 12.000/mês
# 1    de R$ 4.001/mês a R$ 6.000/mês
# 2  de R$ 12.001/mês a R$ 16.000/mês
# 3  de R$ 12.001/mês a R$ 16.000/mês
# 4    de R$ 6.001/mês a R$ 8.000/mês
# 5    de R$ 2.001/mês a R$ 3.000/mês
# 6    de R$ 4.001/mês a R$ 6.000/mês
# 7    de R$ 2.001/mês a R$ 3.000/mês
# 8    de R$ 6.001/mês a R$ 8.000/mês
# 9   de R$ 8.001/mês a R$ 12.000/mês
#
#    QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 0                                      de 1 a 2 anos
# 1                                      de 3 a 4 anos
# 2                                      de 3 a 4 anos
# 3                                      de 4 a 6 anos
# 4             Não tenho experiência na área de dados
# 5             Não tenho experiência na área de dados
# 6                                      de 1 a 2 anos
# 7                                     Menos de 1 ano
# 8                                     Menos de 1 ano
# 9                                    Mais de 10 anos
#
#   QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 0                                     de 7 a 10 anos
# 1                                     Menos de 1 ano
# 2                                    Mais de 10 anos
# 3  Não tive experiência na área de TI/Engenharia ...
# 4                                    Mais de 10 anos
# 5  Não tive experiência na área de TI/Engenharia ...
# 6                                     Menos de 1 ano
# 7                                     Menos de 1 ano
# 8  Não tive experiência na área de TI/Engenharia ...
# 9  Não tive experiência na área de TI/Engenharia ...
#
#    SALARIO
# 0  10000.0
# 1   5000.0
# 2  14000.0
# 3  14000.0
# 4   7000.0
# 5   2500.0
# 6   5000.0
# 7   2500.0
# 8   7000.0
# 9  10000.0
#
# [10 rows x 30 columns]

# %%
#ultimas linhas da tabela, padrão ser 5 ultimas
dados.tail()
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29  Masculino
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34   Feminino
# 4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29  Masculino
# 4269  00xu7yujd7s57emj00xu7y0c3njix3de    NaN       17-21  Masculino
# 4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 4266         Branca  Não                                                NaN
# 4267         Branca  Não  Não acredito que minha experiência profissiona...
# 4268         Branca  Não                                                NaN
# 4269         Branca  Não                                                NaN
# 4270         Branca  Não                                                NaN
#
#       PREJUDICA ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  ...  \
# 4266      False                   NaN            True  ...
# 4267      False                   NaN            True  ...
# 4268      False                   NaN            True  ...
# 4269      False                   NaN            True  ...
# 4270      False                   NaN            True  ...
#
#      NUMERO DE FUNCIONARIOS GESTOR?   NIVEL NOVO NIVEL CARGO COMO GESTOR  \
# 4266         Acima de 3.000   False   Pleno      Pleno               NaN
# 4267            de 51 a 100   False   Pleno      Pleno               NaN
# 4268           de 101 a 500    True     NaN     GESTOR      Gerente/Head
# 4269       de 1.001 a 3.000   False  Júnior     Júnior               NaN
# 4270         de 501 a 1.000   False  Júnior     Júnior               NaN
#
#                                             CARGO ATUAL  \
# 4266                     Analista de Dados/Data Analyst
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...
# 4268                                                NaN
# 4269                                        Outra Opção
# 4270                     Analista de Dados/Data Analyst
#
#                         FAIXA SALARIAL  \
# 4266    de R$ 4.001/mês a R$ 6.000/mês
# 4267    de R$ 3.001/mês a R$ 4.000/mês
# 4268  de R$ 16.001/mês a R$ 20.000/mês
# 4269             Menos de R$ 1.000/mês
# 4270    de R$ 3.001/mês a R$ 4.000/mês
#
#       QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 4266                                      de 3 a 4 anos
# 4267                                      de 1 a 2 anos
# 4268                                      de 4 a 6 anos
# 4269                                     Menos de 1 ano
# 4270                                      de 1 a 2 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 4266                                     de 7 a 10 anos
# 4267  Não tive experiência na área de TI/Engenharia ...
# 4268  Não tive experiência na área de TI/Engenharia ...
# 4269  Não tive experiência na área de TI/Engenharia ...
# 4270  Não tive experiência na área de TI/Engenharia ...
#
#       SALARIO
# 4266   5000.0
# 4267   3500.0
# 4268  18000.0
# 4269   1000.0
# 4270   3500.0
#
# [5 rows x 30 columns]

# %%
#tamanho da tabela (linhas, colunas)
dados.shape
# Out:
# (4271, 30)

# %%
#quantidade de linhas
len(dados)
# Out:
# 4271

# %%
#nome das colunas
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'PREJUDICA',
#        'ASPECTOS_PREJUDICADOS', 'VIVE_NO_BRASIL', 'ESTADO ONDE MORA',
#        'UF ONDE MORA', 'REGIAO ONDE MORA', 'MUDOU DE ESTADO?',
#        'REGIAO DE ORIGEM', 'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO', 'COMPUTAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'NIVEL', 'NOVO NIVEL',
#        'CARGO COMO GESTOR', 'CARGO ATUAL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
#informação (dados) sobre a tabela
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 30 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   ID                                                                                                                         4271 non-null   object
#  1   IDADE                                                                                                                      4197 non-null   float64
#  2   FAIXA IDADE                                                                                                                4271 non-null   object
#  3   GENERO                                                                                                                     4262 non-null   object
#  4   COR/RACA/ETNIA                                                                                                             4271 non-null   object
#  5   PCD                                                                                                                        4271 non-null   object
#  6   EXPERIENCIA_PROFISSIONAL_PREJUDICADA                                                                                       2190 non-null   object
#  7   PREJUDICA                                                                                                                  4271 non-null   bool
#  8   ASPECTOS_PREJUDICADOS                                                                                                      837 non-null    object
#  9   VIVE_NO_BRASIL                                                                                                             4271 non-null   bool
#  10  ESTADO ONDE MORA                                                                                                           4156 non-null   object
#  11  UF ONDE MORA                                                                                                               4156 non-null   object
#  12  REGIAO ONDE MORA                                                                                                           4171 non-null   object
#  13  MUDOU DE ESTADO?                                                                                                           4171 non-null   object
#  14  REGIAO DE ORIGEM                                                                                                           772 non-null    object
#  15  NIVEL DE ENSINO                                                                                                            4271 non-null   object
#  16  ÁREA DE FORMAÇÃO                                                                                                           4149 non-null   object
#  17  COMPUTAÇÃO                                                                                                                 4271 non-null   bool
#  18  QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?                                                                                       4271 non-null   object
#  19  SETOR                                                                                                                      3694 non-null   object
#  20  NUMERO DE FUNCIONARIOS                                                                                                     3694 non-null   object
#  21  GESTOR?                                                                                                                    3694 non-null   object
#  22  NIVEL                                                                                                                      2981 non-null   object
#  23  NOVO NIVEL                                                                                                                 3694 non-null   object
#  24  CARGO COMO GESTOR                                                                                                          713 non-null    object
#  25  CARGO ATUAL                                                                                                                2981 non-null   object
#  26  FAIXA SALARIAL                                                                                                             3694 non-null   object
#  27  QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?                                                                     3694 non-null   object
#  28  QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  3694 non-null   object
#  29  SALARIO                                                                                                                    3694 non-null   float64
# dtypes: bool(3), float64(2), object(25)
# memory usage: 913.6+ KB

# %%
dados.describe()
# Out:
#              IDADE        SALARIO
# count  4197.000000    3694.000000
# mean     31.169168   10305.310774
# std       6.902803   17644.336517
# min      18.000000    1000.000000
# 25%      26.000000    5000.000000
# 50%      30.000000    7000.000000
# 75%      35.000000   14000.000000
# max      54.000000  488710.000000

# %% [markdown]
# #REPETINDO ANÁLISE DO EXCEL

# %%
dados[dados['GENERO']=='Feminino']
# Out:
#                                     ID  IDADE FAIXA IDADE    GENERO  \
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49  Feminino
# 5     zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34  Feminino
# 7     zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34  Feminino
# 9     zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+  Feminino
# 10    zwy34gktg0tfjq2ttjvazwy34gg3g49i   25.0       25-29  Feminino
# ...                                ...    ...         ...       ...
# 4248  070o4zayoboztox764qu070o4zafbqrd   27.0       25-29  Feminino
# 4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34  Feminino
# 4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29  Feminino
# 4259  03n2lq8st9zobnowu3w03n2lqi0flz2w   28.0       25-29  Feminino
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34  Feminino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 4            Branca  Não  Não acredito que minha experiência profissiona...
# 5             Parda  Não  Não acredito que minha experiência profissiona...
# 7            Branca  Não  Não acredito que minha experiência profissiona...
# 9             Parda  Não  Não acredito que minha experiência profissiona...
# 10            Parda  Não  Não acredito que minha experiência profissiona...
# ...             ...  ...                                                ...
# 4248         Branca  Não  Não acredito que minha experiência profissiona...
# 4251          Preta  Não  Não acredito que minha experiência profissiona...
# 4258         Branca  Não  Sim, acredito que a minha a experiência profis...
# 4259         Branca  Não  Sim, acredito que a minha a experiência profis...
# 4267         Branca  Não  Não acredito que minha experiência profissiona...
#
#       PREJUDICA                              ASPECTOS_PREJUDICADOS  \
# 4         False                                                NaN
# 5         False                                                NaN
# 7         False                                                NaN
# 9         False                                                NaN
# 10        False                                                NaN
# ...         ...                                                ...
# 4248      False                                                NaN
# 4251      False                                                NaN
# 4258       True  Senioridade das vagas recebidas em relação à s...
# 4259       True  Relação com outros membros da empresa, em mome...
# 4267      False                                                NaN
#
#       VIVE_NO_BRASIL  ... NUMERO DE FUNCIONARIOS GESTOR?   NIVEL NOVO NIVEL  \
# 4               True  ...           de 101 a 500   False   Pleno      Pleno
# 5               True  ...         Acima de 3.000   False   Pleno      Pleno
# 7               True  ...              de 6 a 10   False  Júnior     Júnior
# 9               True  ...         Acima de 3.000   False   Pleno      Pleno
# 10              True  ...           de 101 a 500   False  Júnior     Júnior
# ...              ...  ...                    ...     ...     ...        ...
# 4248            True  ...           de 101 a 500   False   Pleno      Pleno
# 4251            True  ...       de 1.001 a 3.000   False   Pleno      Pleno
# 4258            True  ...                    NaN     NaN     NaN        NaN
# 4259            True  ...         Acima de 3.000    True     NaN     GESTOR
# 4267            True  ...            de 51 a 100   False   Pleno      Pleno
#
#            CARGO COMO GESTOR  \
# 4                        NaN
# 5                        NaN
# 7                        NaN
# 9                        NaN
# 10                       NaN
# ...                      ...
# 4248                     NaN
# 4251                     NaN
# 4258                     NaN
# 4259  Supervisor/Coordenador
# 4267                     NaN
#
#                                             CARGO ATUAL  \
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...
# 5                                             Professor
# 7     Desenvolvedor/ Engenheiro de Software/ Analist...
# 9                                             Professor
# 10                            Analista de BI/BI Analyst
# ...                                                 ...
# 4248                  Cientista de Dados/Data Scientist
# 4251  Engenheiro de Dados/Arquiteto de Dados/Data En...
# 4258                                                NaN
# 4259                                                NaN
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...
#
#                         FAIXA SALARIAL  \
# 4       de R$ 6.001/mês a R$ 8.000/mês
# 5       de R$ 2.001/mês a R$ 3.000/mês
# 7       de R$ 2.001/mês a R$ 3.000/mês
# 9      de R$ 8.001/mês a R$ 12.000/mês
# 10      de R$ 3.001/mês a R$ 4.000/mês
# ...                                ...
# 4248    de R$ 4.001/mês a R$ 6.000/mês
# 4251    de R$ 4.001/mês a R$ 6.000/mês
# 4258                               NaN
# 4259  de R$ 20.001/mês a R$ 25.000/mês
# 4267    de R$ 3.001/mês a R$ 4.000/mês
#
#       QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 4                Não tenho experiência na área de dados
# 5                Não tenho experiência na área de dados
# 7                                        Menos de 1 ano
# 9                                       Mais de 10 anos
# 10                                       Menos de 1 ano
# ...                                                 ...
# 4248                                      de 1 a 2 anos
# 4251                                     Menos de 1 ano
# 4258                                                NaN
# 4259                                      de 4 a 6 anos
# 4267                                      de 1 a 2 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 4                                       Mais de 10 anos
# 5     Não tive experiência na área de TI/Engenharia ...
# 7                                        Menos de 1 ano
# 9     Não tive experiência na área de TI/Engenharia ...
# 10    Não tive experiência na área de TI/Engenharia ...
# ...                                                 ...
# 4248  Não tive experiência na área de TI/Engenharia ...
# 4251                                     Menos de 1 ano
# 4258                                                NaN
# 4259  Não tive experiência na área de TI/Engenharia ...
# 4267  Não tive experiência na área de TI/Engenharia ...
#
#       SALARIO
# 4      7000.0
# 5      2500.0
# 7      2500.0
# 9     10000.0
# 10     3500.0
# ...       ...
# 4248   5000.0
# 4251   5000.0
# 4258      NaN
# 4259  22500.0
# 4267   3500.0
#
# [1056 rows x 30 columns]

# %%
dados[dados['GENERO']!='Masculino']
# Out:
#                                     ID  IDADE FAIXA IDADE    GENERO  \
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49  Feminino
# 5     zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34  Feminino
# 7     zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34  Feminino
# 9     zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+  Feminino
# 10    zwy34gktg0tfjq2ttjvazwy34gg3g49i   25.0       25-29  Feminino
# ...                                ...    ...         ...       ...
# 4248  070o4zayoboztox764qu070o4zafbqrd   27.0       25-29  Feminino
# 4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34  Feminino
# 4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29  Feminino
# 4259  03n2lq8st9zobnowu3w03n2lqi0flz2w   28.0       25-29  Feminino
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34  Feminino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 4            Branca  Não  Não acredito que minha experiência profissiona...
# 5             Parda  Não  Não acredito que minha experiência profissiona...
# 7            Branca  Não  Não acredito que minha experiência profissiona...
# 9             Parda  Não  Não acredito que minha experiência profissiona...
# 10            Parda  Não  Não acredito que minha experiência profissiona...
# ...             ...  ...                                                ...
# 4248         Branca  Não  Não acredito que minha experiência profissiona...
# 4251          Preta  Não  Não acredito que minha experiência profissiona...
# 4258         Branca  Não  Sim, acredito que a minha a experiência profis...
# 4259         Branca  Não  Sim, acredito que a minha a experiência profis...
# 4267         Branca  Não  Não acredito que minha experiência profissiona...
#
#       PREJUDICA                              ASPECTOS_PREJUDICADOS  \
# 4         False                                                NaN
# 5         False                                                NaN
# 7         False                                                NaN
# 9         False                                                NaN
# 10        False                                                NaN
# ...         ...                                                ...
# 4248      False                                                NaN
# 4251      False                                                NaN
# 4258       True  Senioridade das vagas recebidas em relação à s...
# 4259       True  Relação com outros membros da empresa, em mome...
# 4267      False                                                NaN
#
#       VIVE_NO_BRASIL  ... NUMERO DE FUNCIONARIOS GESTOR?   NIVEL NOVO NIVEL  \
# 4               True  ...           de 101 a 500   False   Pleno      Pleno
# 5               True  ...         Acima de 3.000   False   Pleno      Pleno
# 7               True  ...              de 6 a 10   False  Júnior     Júnior
# 9               True  ...         Acima de 3.000   False   Pleno      Pleno
# 10              True  ...           de 101 a 500   False  Júnior     Júnior
# ...              ...  ...                    ...     ...     ...        ...
# 4248            True  ...           de 101 a 500   False   Pleno      Pleno
# 4251            True  ...       de 1.001 a 3.000   False   Pleno      Pleno
# 4258            True  ...                    NaN     NaN     NaN        NaN
# 4259            True  ...         Acima de 3.000    True     NaN     GESTOR
# 4267            True  ...            de 51 a 100   False   Pleno      Pleno
#
#            CARGO COMO GESTOR  \
# 4                        NaN
# 5                        NaN
# 7                        NaN
# 9                        NaN
# 10                       NaN
# ...                      ...
# 4248                     NaN
# 4251                     NaN
# 4258                     NaN
# 4259  Supervisor/Coordenador
# 4267                     NaN
#
#                                             CARGO ATUAL  \
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...
# 5                                             Professor
# 7     Desenvolvedor/ Engenheiro de Software/ Analist...
# 9                                             Professor
# 10                            Analista de BI/BI Analyst
# ...                                                 ...
# 4248                  Cientista de Dados/Data Scientist
# 4251  Engenheiro de Dados/Arquiteto de Dados/Data En...
# 4258                                                NaN
# 4259                                                NaN
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...
#
#                         FAIXA SALARIAL  \
# 4       de R$ 6.001/mês a R$ 8.000/mês
# 5       de R$ 2.001/mês a R$ 3.000/mês
# 7       de R$ 2.001/mês a R$ 3.000/mês
# 9      de R$ 8.001/mês a R$ 12.000/mês
# 10      de R$ 3.001/mês a R$ 4.000/mês
# ...                                ...
# 4248    de R$ 4.001/mês a R$ 6.000/mês
# 4251    de R$ 4.001/mês a R$ 6.000/mês
# 4258                               NaN
# 4259  de R$ 20.001/mês a R$ 25.000/mês
# 4267    de R$ 3.001/mês a R$ 4.000/mês
#
#       QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 4                Não tenho experiência na área de dados
# 5                Não tenho experiência na área de dados
# 7                                        Menos de 1 ano
# 9                                       Mais de 10 anos
# 10                                       Menos de 1 ano
# ...                                                 ...
# 4248                                      de 1 a 2 anos
# 4251                                     Menos de 1 ano
# 4258                                                NaN
# 4259                                      de 4 a 6 anos
# 4267                                      de 1 a 2 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 4                                       Mais de 10 anos
# 5     Não tive experiência na área de TI/Engenharia ...
# 7                                        Menos de 1 ano
# 9     Não tive experiência na área de TI/Engenharia ...
# 10    Não tive experiência na área de TI/Engenharia ...
# ...                                                 ...
# 4248  Não tive experiência na área de TI/Engenharia ...
# 4251                                     Menos de 1 ano
# 4258                                                NaN
# 4259  Não tive experiência na área de TI/Engenharia ...
# 4267  Não tive experiência na área de TI/Engenharia ...
#
#       SALARIO
# 4      7000.0
# 5      2500.0
# 7      2500.0
# 9     10000.0
# 10     3500.0
# ...       ...
# 4248   5000.0
# 4251   5000.0
# 4258      NaN
# 4259  22500.0
# 4267   3500.0
#
# [1077 rows x 30 columns]

# %%
dados[dados['GENERO'].str.contains('não', na=False)]
# Out:
#                                     ID  IDADE FAIXA IDADE  \
# 562   vhuw8xnpbmj6oh20xovhuwcbdl4a12ni   29.0       25-29
# 1528  n2ktdn33istvlu1ha4v3kn2ktdn1rsp1    NaN         55+
# 1913  k3as6jdh3w4jf4ztsw4kpkk3as6jdy19   30.0       30-34
# 1925  jzppdwep2kpisqjjzppdh304v83cj7eu    NaN       17-21
# 2554  f5l206z0hr9uh3nz2iiff5l206c0g10o   20.0       17-21
# 3090  a6ugmsw7s8hu5aa6uglio5apj74fam9o   26.0       25-29
# 3357  7q0icczxn0l3a894cbx7q0icczjyud0n   29.0       25-29
# 3493  6m8haop6lxnaizpwij6m8haopiax98jg   25.0       25-29
# 3610  5mloglozmr0r715mntaxbt6xy8b5olmb   30.0       30-34
# 4171  0rksyxnqhn13nwytwi6y0rkssx6jmodf   26.0       25-29
# 4200  0liu228yff8fnm3zeuahsx0liu228y07   28.0       25-29
# 4227  0eqzo5w2l5wizswvwywt8h0eqzo5yucv   28.0       25-29
#
#                     GENERO        COR/RACA/ETNIA                   PCD  \
# 562   Prefiro não informar                 Parda                   Não
# 1528  Prefiro não informar              Indígena  Prefiro não informar
# 1913  Prefiro não informar  Prefiro não informar                   Não
# 1925  Prefiro não informar  Prefiro não informar  Prefiro não informar
# 2554  Prefiro não informar  Prefiro não informar                   Não
# 3090  Prefiro não informar                 Parda                   Não
# 3357  Prefiro não informar                 Preta                   Não
# 3493  Prefiro não informar                Branca                   Não
# 3610  Prefiro não informar                Branca                   Não
# 4171  Prefiro não informar                Branca                   Não
# 4200  Prefiro não informar                 Outra                   Não
# 4227  Prefiro não informar                 Preta                   Não
#
#                    EXPERIENCIA_PROFISSIONAL_PREJUDICADA  PREJUDICA  \
# 562   Sim, acredito que a minha a experiência profis...       True
# 1528  Não acredito que minha experiência profissiona...      False
# 1913  Não acredito que minha experiência profissiona...      False
# 1925  Sim, acredito que minha experiência profission...      False
# 2554  Não acredito que minha experiência profissiona...      False
# 3090  Não acredito que minha experiência profissiona...      False
# 3357  Não acredito que minha experiência profissiona...      False
# 3493  Sim, acredito que a minha a experiência profis...       True
# 3610  Sim, acredito que a minha a experiência profis...       True
# 4171  Não acredito que minha experiência profissiona...      False
# 4200  Não acredito que minha experiência profissiona...      False
# 4227  Sim, acredito que a minha a experiência profis...       True
#
#                                   ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  ...  \
# 562   Atenção dada pelas pessoas diante das minhas o...            True  ...
# 1528                                                NaN            True  ...
# 1913                                                NaN            True  ...
# 1925  Quantidade de oportunidades de emprego/vagas r...           False  ...
# 2554                                                NaN            True  ...
# 3090                                                NaN            True  ...
# 3357                                                NaN            True  ...
# 3493  Quantidade de oportunidades de emprego/vagas r...            True  ...
# 3610               Velocidade de progressão de carreira            True  ...
# 4171                                                NaN            True  ...
# 4200                                                NaN            True  ...
# 4227  Atenção dada pelas pessoas diante das minhas o...            True  ...
#
#      NUMERO DE FUNCIONARIOS GESTOR?   NIVEL NOVO NIVEL  \
# 562                     NaN     NaN     NaN        NaN
# 1528            de 51 a 100   False  Júnior     Júnior
# 1913           de 101 a 500   False   Pleno      Pleno
# 1925               de 1 a 5   False  Júnior     Júnior
# 2554         Acima de 3.000   False  Júnior     Júnior
# 3090           de 101 a 500    True     NaN     GESTOR
# 3357       de 1.001 a 3.000   False  Júnior     Júnior
# 3493         Acima de 3.000   False   Pleno      Pleno
# 3610           de 101 a 500   False  Sênior     Sênior
# 4171       de 1.001 a 3.000   False   Pleno      Pleno
# 4200         de 501 a 1.000    True     NaN     GESTOR
# 4227         Acima de 3.000   False   Pleno      Pleno
#
#             CARGO COMO GESTOR  \
# 562                       NaN
# 1528                      NaN
# 1913                      NaN
# 1925                      NaN
# 2554                      NaN
# 3090  Team Leader/Tech Leader
# 3357                      NaN
# 3493                      NaN
# 3610                      NaN
# 4171                      NaN
# 4200  Team Leader/Tech Leader
# 4227                      NaN
#
#                                             CARGO ATUAL  \
# 562                                                 NaN
# 1528               Analista de Suporte/Analista Técnico
# 1913                     Analista de Dados/Data Analyst
# 1925                                        Outra Opção
# 2554                  Cientista de Dados/Data Scientist
# 3090                                                NaN
# 3357  Engenheiro de Dados/Arquiteto de Dados/Data En...
# 3493                     Analista de Dados/Data Analyst
# 3610  Engenheiro de Dados/Arquiteto de Dados/Data En...
# 4171                     Analista de Dados/Data Analyst
# 4200                                                NaN
# 4227  Product Manager/ Product Owner (PM/APM/DPM/GPM...
#
#                         FAIXA SALARIAL  \
# 562                                NaN
# 1528             Menos de R$ 1.000/mês
# 1913   de R$ 8.001/mês a R$ 12.000/mês
# 1925    de R$ 2.001/mês a R$ 3.000/mês
# 2554    de R$ 1.001/mês a R$ 2.000/mês
# 3090   de R$ 8.001/mês a R$ 12.000/mês
# 3357    de R$ 6.001/mês a R$ 8.000/mês
# 3493    de R$ 3.001/mês a R$ 4.000/mês
# 3610   de R$ 8.001/mês a R$ 12.000/mês
# 4171   de R$ 8.001/mês a R$ 12.000/mês
# 4200  de R$ 16.001/mês a R$ 20.000/mês
# 4227    de R$ 6.001/mês a R$ 8.000/mês
#
#       QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 562                                                 NaN
# 1528                                     Menos de 1 ano
# 1913                                    Mais de 10 anos
# 1925                                      de 1 a 2 anos
# 2554                                      de 1 a 2 anos
# 3090                                      de 1 a 2 anos
# 3357                                     Menos de 1 ano
# 3493                                      de 3 a 4 anos
# 3610                                      de 3 a 4 anos
# 4171                                      de 1 a 2 anos
# 4200                                    Mais de 10 anos
# 4227                                     Menos de 1 ano
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 562                                                 NaN
# 1528                                     Menos de 1 ano
# 1913                                      de 3 a 4 anos
# 1925                                     Menos de 1 ano
# 2554                                      de 1 a 2 anos
# 3090  Não tive experiência na área de TI/Engenharia ...
# 3357  Não tive experiência na área de TI/Engenharia ...
# 3493                                     Menos de 1 ano
# 3610  Não tive experiência na área de TI/Engenharia ...
# 4171                                     Menos de 1 ano
# 4200                                     de 7 a 10 anos
# 4227  Não tive experiência na área de TI/Engenharia ...
#
#       SALARIO
# 562       NaN
# 1528   1000.0
# 1913  10000.0
# 1925   2500.0
# 2554   1500.0
# 3090  10000.0
# 3357   7000.0
# 3493   3500.0
# 3610  10000.0
# 4171  10000.0
# 4200  18000.0
# 4227   7000.0
#
# [12 rows x 30 columns]

# %%
dados[dados['IDADE']>30]
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 0     zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1     zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2     zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
# 5     zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34   Feminino
# ...                                ...    ...         ...        ...
# 4257  043snvbsxn3fuyfe043j5comuyu8g6ba   46.0       45-49  Masculino
# 4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39  Masculino
# 4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34  Masculino
# 4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34  Masculino
# 4264  028mfisr3mqazkn5n6swe028mt55nqzq   37.0       35-39  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0             Parda  Não  Não acredito que minha experiência profissiona...
# 1             Parda  Não  Sim, acredito que a minha a experiência profis...
# 2            Branca  Não                                                NaN
# 4            Branca  Não  Não acredito que minha experiência profissiona...
# 5             Parda  Não  Não acredito que minha experiência profissiona...
# ...             ...  ...                                                ...
# 4257        Amarela  Não  Não acredito que minha experiência profissiona...
# 4260          Parda  Não  Não acredito que minha experiência profissiona...
# 4261         Branca  Não                                                NaN
# 4262        Amarela  Não  Não acredito que minha experiência profissiona...
# 4264         Branca  Não                                                NaN
#
#       PREJUDICA                         ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 0         False                                           NaN            True
# 1          True  Aprovação em processos seletivos/entrevistas            True
# 2         False                                           NaN            True
# 4         False                                           NaN            True
# 5         False                                           NaN            True
# ...         ...                                           ...             ...
# 4257      False                                           NaN            True
# 4260      False                                           NaN            True
# 4261      False                                           NaN            True
# 4262      False                                           NaN            True
# 4264      False                                           NaN            True
#
#       ... NUMERO DE FUNCIONARIOS GESTOR?   NIVEL NOVO NIVEL  \
# 0     ...         Acima de 3.000   False  Júnior     Júnior
# 1     ...         Acima de 3.000    True     NaN     GESTOR
# 2     ...         Acima de 3.000   False   Pleno      Pleno
# 4     ...           de 101 a 500   False   Pleno      Pleno
# 5     ...         Acima de 3.000   False   Pleno      Pleno
# ...   ...                    ...     ...     ...        ...
# 4257  ...         Acima de 3.000    True     NaN     GESTOR
# 4260  ...                    NaN     NaN     NaN        NaN
# 4261  ...                    NaN     NaN     NaN        NaN
# 4262  ...         de 501 a 1.000    True     NaN     GESTOR
# 4264  ...            de 51 a 100    True     NaN     GESTOR
#
#             CARGO COMO GESTOR  \
# 0                         NaN
# 1      Supervisor/Coordenador
# 2                         NaN
# 4                         NaN
# 5                         NaN
# ...                       ...
# 4257             Gerente/Head
# 4260                      NaN
# 4261                      NaN
# 4262  Team Leader/Tech Leader
# 4264             Gerente/Head
#
#                                             CARGO ATUAL  \
# 0                   DBA/Administrador de Banco de Dados
# 1                                                   NaN
# 2     Desenvolvedor/ Engenheiro de Software/ Analist...
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...
# 5                                             Professor
# ...                                                 ...
# 4257                                                NaN
# 4260                                                NaN
# 4261                                                NaN
# 4262                                                NaN
# 4264                                                NaN
#
#                         FAIXA SALARIAL  \
# 0      de R$ 8.001/mês a R$ 12.000/mês
# 1       de R$ 4.001/mês a R$ 6.000/mês
# 2     de R$ 12.001/mês a R$ 16.000/mês
# 4       de R$ 6.001/mês a R$ 8.000/mês
# 5       de R$ 2.001/mês a R$ 3.000/mês
# ...                                ...
# 4257            Acima de R$ 40.001/mês
# 4260                               NaN
# 4261                               NaN
# 4262  de R$ 16.001/mês a R$ 20.000/mês
# 4264  de R$ 20.001/mês a R$ 25.000/mês
#
#       QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 0                                         de 1 a 2 anos
# 1                                         de 3 a 4 anos
# 2                                         de 3 a 4 anos
# 4                Não tenho experiência na área de dados
# 5                Não tenho experiência na área de dados
# ...                                                 ...
# 4257                                    Mais de 10 anos
# 4260                                                NaN
# 4261                                                NaN
# 4262                                      de 3 a 4 anos
# 4264                                      de 3 a 4 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 0                                        de 7 a 10 anos
# 1                                        Menos de 1 ano
# 2                                       Mais de 10 anos
# 4                                       Mais de 10 anos
# 5     Não tive experiência na área de TI/Engenharia ...
# ...                                                 ...
# 4257  Não tive experiência na área de TI/Engenharia ...
# 4260                                                NaN
# 4261                                                NaN
# 4262                                      de 3 a 4 anos
# 4264                                    Mais de 10 anos
#
#       SALARIO
# 0     10000.0
# 1      5000.0
# 2     14000.0
# 4      7000.0
# 5      2500.0
# ...       ...
# 4257  40000.0
# 4260      NaN
# 4261      NaN
# 4262  18000.0
# 4264  22500.0
#
# [1956 rows x 30 columns]

# %%
dados[(dados['IDADE']>30) & (dados['GENERO']=='Feminino')]
# Out:
#                                     ID  IDADE FAIXA IDADE    GENERO  \
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49  Feminino
# 5     zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34  Feminino
# 7     zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34  Feminino
# 14    zwez49k0jhdvfkfst4zwef137uuf4ivy   35.0       35-39  Feminino
# 23    zuqfcwtl9unfc5ezuqfcwm8coytsp5ap   46.0       45-49  Feminino
# ...                                ...    ...         ...       ...
# 4214  0gprow0ownrbfneftxf0gprow4kyrqdy   41.0       40-44  Feminino
# 4221  0fgi5bnb0u9b0fgc0jmqlbnvtu12b76d   34.0       30-34  Feminino
# 4240  0a5xgxb1ljmuqn0un8a10a5xg4eufs2l   37.0       35-39  Feminino
# 4247  07qzabp4ujpe4oz81udmb07qzabp4h0t   34.0       30-34  Feminino
# 4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34  Feminino
#
#      COR/RACA/ETNIA                   PCD  \
# 4            Branca                   Não
# 5             Parda                   Não
# 7            Branca                   Não
# 14            Parda                   Não
# 23           Branca                   Não
# ...             ...                   ...
# 4214         Branca  Prefiro não informar
# 4221          Outra                   Não
# 4240         Branca                   Não
# 4247         Branca                   Não
# 4251          Preta                   Não
#
#                    EXPERIENCIA_PROFISSIONAL_PREJUDICADA  PREJUDICA  \
# 4     Não acredito que minha experiência profissiona...      False
# 5     Não acredito que minha experiência profissiona...      False
# 7     Não acredito que minha experiência profissiona...      False
# 14    Sim, acredito que a minha a experiência profis...      False
# 23    Não acredito que minha experiência profissiona...      False
# ...                                                 ...        ...
# 4214  Sim, acredito que a minha a experiência profis...       True
# 4221  Não acredito que minha experiência profissiona...      False
# 4240  Sim, acredito que a minha a experiência profis...       True
# 4247  Não acredito que minha experiência profissiona...      False
# 4251  Não acredito que minha experiência profissiona...      False
#
#                                   ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  ...  \
# 4                                                   NaN            True  ...
# 5                                                   NaN            True  ...
# 7                                                   NaN            True  ...
# 14    Atenção dada pelas pessoas diante das minhas o...            True  ...
# 23                                                  NaN            True  ...
# ...                                                 ...             ...  ...
# 4214  Oportunidades de progressão de carreira, Veloc...            True  ...
# 4221                                                NaN            True  ...
# 4240  Quantidade de oportunidades de emprego/vagas r...            True  ...
# 4247                                                NaN            True  ...
# 4251                                                NaN            True  ...
#
#      NUMERO DE FUNCIONARIOS GESTOR?   NIVEL NOVO NIVEL  \
# 4              de 101 a 500   False   Pleno      Pleno
# 5            Acima de 3.000   False   Pleno      Pleno
# 7                 de 6 a 10   False  Júnior     Júnior
# 14           Acima de 3.000   False   Pleno      Pleno
# 23           de 501 a 1.000   False  Sênior     Sênior
# ...                     ...     ...     ...        ...
# 4214         Acima de 3.000    True     NaN     GESTOR
# 4221            de 51 a 100   False  Júnior     Júnior
# 4240            de 51 a 100   False  Júnior     Júnior
# 4247             de 11 a 50   False  Júnior     Júnior
# 4251       de 1.001 a 3.000   False   Pleno      Pleno
#
#            CARGO COMO GESTOR  \
# 4                        NaN
# 5                        NaN
# 7                        NaN
# 14                       NaN
# 23                       NaN
# ...                      ...
# 4214  Supervisor/Coordenador
# 4221                     NaN
# 4240                     NaN
# 4247                     NaN
# 4251                     NaN
#
#                                             CARGO ATUAL  \
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...
# 5                                             Professor
# 7     Desenvolvedor/ Engenheiro de Software/ Analist...
# 14                Analista de Negócios/Business Analyst
# 23    Engenheiro de Dados/Arquiteto de Dados/Data En...
# ...                                                 ...
# 4214                                                NaN
# 4221                                        Outra Opção
# 4240                          Analista de BI/BI Analyst
# 4247                  Cientista de Dados/Data Scientist
# 4251  Engenheiro de Dados/Arquiteto de Dados/Data En...
#
#                         FAIXA SALARIAL  \
# 4       de R$ 6.001/mês a R$ 8.000/mês
# 5       de R$ 2.001/mês a R$ 3.000/mês
# 7       de R$ 2.001/mês a R$ 3.000/mês
# 14      de R$ 6.001/mês a R$ 8.000/mês
# 23    de R$ 12.001/mês a R$ 16.000/mês
# ...                                ...
# 4214   de R$ 8.001/mês a R$ 12.000/mês
# 4221    de R$ 4.001/mês a R$ 6.000/mês
# 4240    de R$ 1.001/mês a R$ 2.000/mês
# 4247    de R$ 4.001/mês a R$ 6.000/mês
# 4251    de R$ 4.001/mês a R$ 6.000/mês
#
#       QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 4                Não tenho experiência na área de dados
# 5                Não tenho experiência na área de dados
# 7                                        Menos de 1 ano
# 14                                        de 1 a 2 anos
# 23                                      Mais de 10 anos
# ...                                                 ...
# 4214                                      de 4 a 6 anos
# 4221                                     Menos de 1 ano
# 4240                                      de 1 a 2 anos
# 4247                                    Mais de 10 anos
# 4251                                     Menos de 1 ano
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 4                                       Mais de 10 anos
# 5     Não tive experiência na área de TI/Engenharia ...
# 7                                        Menos de 1 ano
# 14    Não tive experiência na área de TI/Engenharia ...
# 23                                        de 5 a 6 anos
# ...                                                 ...
# 4214  Não tive experiência na área de TI/Engenharia ...
# 4221                                     Menos de 1 ano
# 4240                                     Menos de 1 ano
# 4247  Não tive experiência na área de TI/Engenharia ...
# 4251                                     Menos de 1 ano
#
#       SALARIO
# 4      7000.0
# 5      2500.0
# 7      2500.0
# 14     7000.0
# 23    14000.0
# ...       ...
# 4214  10000.0
# 4221   5000.0
# 4240   1500.0
# 4247   5000.0
# 4251   5000.0
#
# [503 rows x 30 columns]

# %%
dados[dados['COR/RACA/ETNIA'] == 'Amarela']
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 13    zwh83jpy6x40b95xigsr2zwh83jpflu3   24.0       22-24  Masculino
# 85    zfeuk2m9jozahicujlla8zfeuk2g7apj   29.0       25-29   Feminino
# 97    zbukfwxvpwlk6loglm0zbukfwx6bvyb6   40.0       40-44  Masculino
# 107   z9toybzbja7n6xjjbz9f8hmofrry69tg   44.0       40-44  Masculino
# 159   ytrnz3zyvn791t3dum1ytrnz3zp22tmk   37.0       35-39   Feminino
# ...                                ...    ...         ...        ...
# 4176  0qpa64gqpieg60xpygnajt70qpa64g1a   27.0       25-29   Feminino
# 4207  0ibb8fj9qrwpswfqiil0ibb89e3e4hz3   30.0       30-34   Feminino
# 4210  0hbwm1d1wz739r40hbwm1df6ky5kn4ap   43.0       40-44   Feminino
# 4257  043snvbsxn3fuyfe043j5comuyu8g6ba   46.0       45-49  Masculino
# 4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 13          Amarela  Não  Não acredito que minha experiência profissiona...
# 85          Amarela  Não  Não acredito que minha experiência profissiona...
# 97          Amarela  Não  Não acredito que minha experiência profissiona...
# 107         Amarela  Não  Não acredito que minha experiência profissiona...
# 159         Amarela  Não  Sim, acredito que a minha a experiência profis...
# ...             ...  ...                                                ...
# 4176        Amarela  Não  Não acredito que minha experiência profissiona...
# 4207        Amarela  Não  Sim, acredito que a minha a experiência profis...
# 4210        Amarela  Não  Não acredito que minha experiência profissiona...
# 4257        Amarela  Não  Não acredito que minha experiência profissiona...
# 4262        Amarela  Não  Não acredito que minha experiência profissiona...
#
#       PREJUDICA                              ASPECTOS_PREJUDICADOS  \
# 13        False                                                NaN
# 85        False                                                NaN
# 97        False                                                NaN
# 107       False                                                NaN
# 159       False  Oportunidades de progressão de carreira, Aprov...
# ...         ...                                                ...
# 4176      False                                                NaN
# 4207       True  Oportunidades de progressão de carreira, Veloc...
# 4210      False                                                NaN
# 4257      False                                                NaN
# 4262      False                                                NaN
#
#       VIVE_NO_BRASIL  ... NUMERO DE FUNCIONARIOS GESTOR?   NIVEL NOVO NIVEL  \
# 13              True  ...         Acima de 3.000   False  Júnior     Júnior
# 85              True  ...                    NaN     NaN     NaN        NaN
# 97              True  ...         Acima de 3.000   False  Sênior     Sênior
# 107             True  ...         Acima de 3.000   False  Sênior     Sênior
# 159             True  ...           de 101 a 500   False   Pleno      Pleno
# ...              ...  ...                    ...     ...     ...        ...
# 4176            True  ...                    NaN     NaN     NaN        NaN
# 4207            True  ...         de 501 a 1.000   False  Sênior     Sênior
# 4210            True  ...         Acima de 3.000   False  Sênior     Sênior
# 4257            True  ...         Acima de 3.000    True     NaN     GESTOR
# 4262            True  ...         de 501 a 1.000    True     NaN     GESTOR
#
#             CARGO COMO GESTOR  \
# 13                        NaN
# 85                        NaN
# 97                        NaN
# 107                       NaN
# 159                       NaN
# ...                       ...
# 4176                      NaN
# 4207                      NaN
# 4210                      NaN
# 4257             Gerente/Head
# 4262  Team Leader/Tech Leader
#
#                                             CARGO ATUAL  \
# 13                Analista de Negócios/Business Analyst
# 85                                                  NaN
# 97                            Analista de BI/BI Analyst
# 107   Engenheiro de Dados/Arquiteto de Dados/Data En...
# 159   Engenheiro de Dados/Arquiteto de Dados/Data En...
# ...                                                 ...
# 4176                                                NaN
# 4207                  Cientista de Dados/Data Scientist
# 4210  Desenvolvedor/ Engenheiro de Software/ Analist...
# 4257                                                NaN
# 4262                                                NaN
#
#                         FAIXA SALARIAL  \
# 13      de R$ 4.001/mês a R$ 6.000/mês
# 85                                 NaN
# 97     de R$ 8.001/mês a R$ 12.000/mês
# 107   de R$ 12.001/mês a R$ 16.000/mês
# 159    de R$ 8.001/mês a R$ 12.000/mês
# ...                                ...
# 4176                               NaN
# 4207  de R$ 16.001/mês a R$ 20.000/mês
# 4210    de R$ 6.001/mês a R$ 8.000/mês
# 4257            Acima de R$ 40.001/mês
# 4262  de R$ 16.001/mês a R$ 20.000/mês
#
#       QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 13                                        de 1 a 2 anos
# 85                                                  NaN
# 97                                        de 4 a 6 anos
# 107                                     Mais de 10 anos
# 159                                       de 1 a 2 anos
# ...                                                 ...
# 4176                                                NaN
# 4207                                      de 4 a 6 anos
# 4210                                      de 1 a 2 anos
# 4257                                    Mais de 10 anos
# 4262                                      de 3 a 4 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 13                                       Menos de 1 ano
# 85                                                  NaN
# 97                                      Mais de 10 anos
# 107                                     Mais de 10 anos
# 159                                      de 7 a 10 anos
# ...                                                 ...
# 4176                                                NaN
# 4207                                      de 5 a 6 anos
# 4210                                    Mais de 10 anos
# 4257  Não tive experiência na área de TI/Engenharia ...
# 4262                                      de 3 a 4 anos
#
#       SALARIO
# 13     5000.0
# 85        NaN
# 97    10000.0
# 107   14000.0
# 159   10000.0
# ...       ...
# 4176      NaN
# 4207  18000.0
# 4210   7000.0
# 4257  40000.0
# 4262  18000.0
#
# [128 rows x 30 columns]

# %%
dados[dados['IDADE']< 40]
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 0     zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1     zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 3     zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 5     zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34   Feminino
# 6     zytlxsdgalh22cgrijvzytlxa49i8yzx   21.0       17-21  Masculino
# ...                                ...    ...         ...        ...
# 4265  01nmlhyw8w2b4stchg01nmlvlcqp0iis   28.0       25-29  Masculino
# 4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29  Masculino
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34   Feminino
# 4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29  Masculino
# 4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0             Parda  Não  Não acredito que minha experiência profissiona...
# 1             Parda  Não  Sim, acredito que a minha a experiência profis...
# 3            Branca  Não                                                NaN
# 5             Parda  Não  Não acredito que minha experiência profissiona...
# 6             Parda  Não  Não acredito que minha experiência profissiona...
# ...             ...  ...                                                ...
# 4265         Branca  Não                                                NaN
# 4266         Branca  Não                                                NaN
# 4267         Branca  Não  Não acredito que minha experiência profissiona...
# 4268         Branca  Não                                                NaN
# 4270         Branca  Não                                                NaN
#
#       PREJUDICA                         ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 0         False                                           NaN            True
# 1          True  Aprovação em processos seletivos/entrevistas            True
# 3         False                                           NaN            True
# 5         False                                           NaN            True
# 6         False                                           NaN            True
# ...         ...                                           ...             ...
# 4265      False                                           NaN            True
# 4266      False                                           NaN            True
# 4267      False                                           NaN            True
# 4268      False                                           NaN            True
# 4270      False                                           NaN            True
#
#       ... NUMERO DE FUNCIONARIOS GESTOR?   NIVEL NOVO NIVEL  \
# 0     ...         Acima de 3.000   False  Júnior     Júnior
# 1     ...         Acima de 3.000    True     NaN     GESTOR
# 3     ...         Acima de 3.000   False  Sênior     Sênior
# 5     ...         Acima de 3.000   False   Pleno      Pleno
# 6     ...         Acima de 3.000   False  Júnior     Júnior
# ...   ...                    ...     ...     ...        ...
# 4265  ...               de 1 a 5   False   Pleno      Pleno
# 4266  ...         Acima de 3.000   False   Pleno      Pleno
# 4267  ...            de 51 a 100   False   Pleno      Pleno
# 4268  ...           de 101 a 500    True     NaN     GESTOR
# 4270  ...         de 501 a 1.000   False  Júnior     Júnior
#
#            CARGO COMO GESTOR  \
# 0                        NaN
# 1     Supervisor/Coordenador
# 3                        NaN
# 5                        NaN
# 6                        NaN
# ...                      ...
# 4265                     NaN
# 4266                     NaN
# 4267                     NaN
# 4268            Gerente/Head
# 4270                     NaN
#
#                                             CARGO ATUAL  \
# 0                   DBA/Administrador de Banco de Dados
# 1                                                   NaN
# 3                     Cientista de Dados/Data Scientist
# 5                                             Professor
# 6                             Analista de BI/BI Analyst
# ...                                                 ...
# 4265                              Analista de Marketing
# 4266                     Analista de Dados/Data Analyst
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...
# 4268                                                NaN
# 4270                     Analista de Dados/Data Analyst
#
#                         FAIXA SALARIAL  \
# 0      de R$ 8.001/mês a R$ 12.000/mês
# 1       de R$ 4.001/mês a R$ 6.000/mês
# 3     de R$ 12.001/mês a R$ 16.000/mês
# 5       de R$ 2.001/mês a R$ 3.000/mês
# 6       de R$ 4.001/mês a R$ 6.000/mês
# ...                                ...
# 4265    de R$ 2.001/mês a R$ 3.000/mês
# 4266    de R$ 4.001/mês a R$ 6.000/mês
# 4267    de R$ 3.001/mês a R$ 4.000/mês
# 4268  de R$ 16.001/mês a R$ 20.000/mês
# 4270    de R$ 3.001/mês a R$ 4.000/mês
#
#       QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 0                                         de 1 a 2 anos
# 1                                         de 3 a 4 anos
# 3                                         de 4 a 6 anos
# 5                Não tenho experiência na área de dados
# 6                                         de 1 a 2 anos
# ...                                                 ...
# 4265                                      de 3 a 4 anos
# 4266                                      de 3 a 4 anos
# 4267                                      de 1 a 2 anos
# 4268                                      de 4 a 6 anos
# 4270                                      de 1 a 2 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 0                                        de 7 a 10 anos
# 1                                        Menos de 1 ano
# 3     Não tive experiência na área de TI/Engenharia ...
# 5     Não tive experiência na área de TI/Engenharia ...
# 6                                        Menos de 1 ano
# ...                                                 ...
# 4265                                      de 1 a 2 anos
# 4266                                     de 7 a 10 anos
# 4267  Não tive experiência na área de TI/Engenharia ...
# 4268  Não tive experiência na área de TI/Engenharia ...
# 4270  Não tive experiência na área de TI/Engenharia ...
#
#       SALARIO
# 0     10000.0
# 1      5000.0
# 3     14000.0
# 5      2500.0
# 6      5000.0
# ...       ...
# 4265   2500.0
# 4266   5000.0
# 4267   3500.0
# 4268  18000.0
# 4270   3500.0
#
# [3686 rows x 30 columns]

# %%
dados[(dados['COR/RACA/ETNIA'] == 'Amarela') & (dados['IDADE']<40)]
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 13    zwh83jpy6x40b95xigsr2zwh83jpflu3   24.0       22-24  Masculino
# 85    zfeuk2m9jozahicujlla8zfeuk2g7apj   29.0       25-29   Feminino
# 159   ytrnz3zyvn791t3dum1ytrnz3zp22tmk   37.0       35-39   Feminino
# 170   yri3z491ejizlpj9ylu2k3jyri3z4915   34.0       30-34  Masculino
# 195   yjbpxmkqz5yidh5oszyjbpxmkgcb1zd9   32.0       30-34  Masculino
# ...                                ...    ...         ...        ...
# 3947  2tnsh0gxdu3aq4z2d2tnsh0hk15brx7q   31.0       30-34   Feminino
# 4058  1t3ndwx8j50k0bz1t3ndwxdpwyg17c2k   27.0       25-29   Feminino
# 4176  0qpa64gqpieg60xpygnajt70qpa64g1a   27.0       25-29   Feminino
# 4207  0ibb8fj9qrwpswfqiil0ibb89e3e4hz3   30.0       30-34   Feminino
# 4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 13          Amarela  Não  Não acredito que minha experiência profissiona...
# 85          Amarela  Não  Não acredito que minha experiência profissiona...
# 159         Amarela  Não  Sim, acredito que a minha a experiência profis...
# 170         Amarela  Não  Não acredito que minha experiência profissiona...
# 195         Amarela  Não  Não acredito que minha experiência profissiona...
# ...             ...  ...                                                ...
# 3947        Amarela  Não  Sim, acredito que a minha a experiência profis...
# 4058        Amarela  Não  Sim, acredito que a minha a experiência profis...
# 4176        Amarela  Não  Não acredito que minha experiência profissiona...
# 4207        Amarela  Não  Sim, acredito que a minha a experiência profis...
# 4262        Amarela  Não  Não acredito que minha experiência profissiona...
#
#       PREJUDICA                              ASPECTOS_PREJUDICADOS  \
# 13        False                                                NaN
# 85        False                                                NaN
# 159       False  Oportunidades de progressão de carreira, Aprov...
# 170       False                                                NaN
# 195       False                                                NaN
# ...         ...                                                ...
# 3947      False  Quantidade de oportunidades de emprego/vagas r...
# 4058       True  Nível de cobrança no trabalho / Stress no trab...
# 4176      False                                                NaN
# 4207       True  Oportunidades de progressão de carreira, Veloc...
# 4262      False                                                NaN
#
#       VIVE_NO_BRASIL  ... NUMERO DE FUNCIONARIOS GESTOR?   NIVEL NOVO NIVEL  \
# 13              True  ...         Acima de 3.000   False  Júnior     Júnior
# 85              True  ...                    NaN     NaN     NaN        NaN
# 159             True  ...           de 101 a 500   False   Pleno      Pleno
# 170             True  ...         Acima de 3.000    True     NaN     GESTOR
# 195             True  ...                    NaN     NaN     NaN        NaN
# ...              ...  ...                    ...     ...     ...        ...
# 3947           False  ...         Acima de 3.000    True     NaN     GESTOR
# 4058            True  ...         Acima de 3.000   False  Sênior     Sênior
# 4176            True  ...                    NaN     NaN     NaN        NaN
# 4207            True  ...         de 501 a 1.000   False  Sênior     Sênior
# 4262            True  ...         de 501 a 1.000    True     NaN     GESTOR
#
#             CARGO COMO GESTOR  \
# 13                        NaN
# 85                        NaN
# 159                       NaN
# 170              Gerente/Head
# 195                       NaN
# ...                       ...
# 3947   Supervisor/Coordenador
# 4058                      NaN
# 4176                      NaN
# 4207                      NaN
# 4262  Team Leader/Tech Leader
#
#                                             CARGO ATUAL  \
# 13                Analista de Negócios/Business Analyst
# 85                                                  NaN
# 159   Engenheiro de Dados/Arquiteto de Dados/Data En...
# 170                                                 NaN
# 195                                                 NaN
# ...                                                 ...
# 3947                                                NaN
# 4058                  Cientista de Dados/Data Scientist
# 4176                                                NaN
# 4207                  Cientista de Dados/Data Scientist
# 4262                                                NaN
#
#                         FAIXA SALARIAL  \
# 13      de R$ 4.001/mês a R$ 6.000/mês
# 85                                 NaN
# 159    de R$ 8.001/mês a R$ 12.000/mês
# 170   de R$ 16.001/mês a R$ 20.000/mês
# 195                                NaN
# ...                                ...
# 3947  de R$ 25.001/mês a R$ 30.000/mês
# 4058  de R$ 12.001/mês a R$ 16.000/mês
# 4176                               NaN
# 4207  de R$ 16.001/mês a R$ 20.000/mês
# 4262  de R$ 16.001/mês a R$ 20.000/mês
#
#       QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 13                                        de 1 a 2 anos
# 85                                                  NaN
# 159                                       de 1 a 2 anos
# 170                                       de 3 a 4 anos
# 195                                                 NaN
# ...                                                 ...
# 3947                                      de 1 a 2 anos
# 4058                                      de 4 a 6 anos
# 4176                                                NaN
# 4207                                      de 4 a 6 anos
# 4262                                      de 3 a 4 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 13                                       Menos de 1 ano
# 85                                                  NaN
# 159                                      de 7 a 10 anos
# 170   Não tive experiência na área de TI/Engenharia ...
# 195                                                 NaN
# ...                                                 ...
# 3947  Não tive experiência na área de TI/Engenharia ...
# 4058  Não tive experiência na área de TI/Engenharia ...
# 4176                                                NaN
# 4207                                      de 5 a 6 anos
# 4262                                      de 3 a 4 anos
#
#       SALARIO
# 13     5000.0
# 85        NaN
# 159   10000.0
# 170   18000.0
# 195       NaN
# ...       ...
# 3947  27500.0
# 4058  14000.0
# 4176      NaN
# 4207  18000.0
# 4262  18000.0
#
# [101 rows x 30 columns]

# %%
dados.groupby('GENERO')['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# Name: ID, dtype: int64

# %%
dados.groupby('GENERO', dropna=False)['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %%
dados['GENERO'].value_counts(dropna=False)
# Out:
# GENERO
# Masculino               3194
# Feminino                1056
# Prefiro não informar      12
# NaN                        9
# Name: count, dtype: int64

# %%
dados[dados['IDADE']>30]['NIVEL'].value_counts()
# Out:
# NIVEL
# Sênior    525
# Pleno     408
# Júnior    274
# Name: count, dtype: int64

# %%
dados[(dados['IDADE']>30) & (dados['GENERO']=='Feminino')]['NIVEL'].value_counts()
# Out:
# NIVEL
# Pleno     117
# Sênior    114
# Júnior     96
# Name: count, dtype: int64

# %%
pd.pivot_table(dados, values = ['ID'], index = ['GENERO'], columns=['GESTOR?'], aggfunc='count')
# Out:
#                         ID
# GESTOR?              False True
# GENERO
# Feminino               754   132
# Masculino             2212   578
# Prefiro não informar     9     2

# %% [markdown]
# #ESTATISTICA BÁSICA

# %%
import numpy as np

# %%
lista_idades = [26,30,32,22,26,35,40,20,43,31,23,100]

# %%
#SOMANDO VALORES DA TABELA
np.sum(lista_idades)
# Out:
# np.int64(428)

# %%
len(lista_idades)
# Out:
# 12

# %%
#MEDIA "MANUAL"
np.sum(lista_idades)/len(lista_idades)
# Out:
# np.float64(35.666666666666664)

# %%
#FUNCAO MEDIA
media = np.mean(lista_idades)
print("Média:", media)
# Out:
# Média: 35.666666666666664

# %%
#ORDENANDO A LISTA DE
lista_idades.sort()

# %%
lista_idades
# Out:
# [20, 22, 23, 26, 26, 30, 31, 32, 35, 40, 43, 100]

# %%
#FUNCAO MEDIANA
mediana = np.median(lista_idades)
mediana
# Out:
# np.float64(30.5)

# %% [markdown]
# ###VOLTANDO PARA TABELA

# %%
#MEDIA
dados['IDADE'].mean()
# Out:
# np.float64(31.169168453657374)

# %%
#MEDIANA
dados['IDADE'].median()
# Out:
# 30.0

# %%
#MODA
dados['IDADE'].mode()
# Out:
# 0    27.0
# Name: IDADE, dtype: float64

# %%
#DESVIO PADRAO
dados['IDADE'].std()
# Out:
# 6.902802832143141

# %%
#VALOR MAXIMO
dados['IDADE'].max()
# Out:
# 54.0

# %%
#VALOR MINIMO
dados['IDADE'].min()
# Out:
# 18.0

# %%
dados[dados['GENERO']=='Feminino']['IDADE'].mean()
# Out:
# np.float64(31.318051575931232)

# %%
dados[dados['GENERO']=='Feminino']['SALARIO'].mean()
# Out:
# np.float64(8293.453724604966)

# %% [markdown]
# #VALORES FALTANTES

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 30 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   ID                                                                                                                         4271 non-null   object
#  1   IDADE                                                                                                                      4197 non-null   float64
#  2   FAIXA IDADE                                                                                                                4271 non-null   object
#  3   GENERO                                                                                                                     4262 non-null   object
#  4   COR/RACA/ETNIA                                                                                                             4271 non-null   object
#  5   PCD                                                                                                                        4271 non-null   object
#  6   EXPERIENCIA_PROFISSIONAL_PREJUDICADA                                                                                       2190 non-null   object
#  7   PREJUDICA                                                                                                                  4271 non-null   bool
#  8   ASPECTOS_PREJUDICADOS                                                                                                      837 non-null    object
#  9   VIVE_NO_BRASIL                                                                                                             4271 non-null   bool
#  10  ESTADO ONDE MORA                                                                                                           4156 non-null   object
#  11  UF ONDE MORA                                                                                                               4156 non-null   object
#  12  REGIAO ONDE MORA                                                                                                           4171 non-null   object
#  13  MUDOU DE ESTADO?                                                                                                           4171 non-null   object
#  14  REGIAO DE ORIGEM                                                                                                           772 non-null    object
#  15  NIVEL DE ENSINO                                                                                                            4271 non-null   object
#  16  ÁREA DE FORMAÇÃO                                                                                                           4149 non-null   object
#  17  COMPUTAÇÃO                                                                                                                 4271 non-null   bool
#  18  QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?                                                                                       4271 non-null   object
#  19  SETOR                                                                                                                      3694 non-null   object
#  20  NUMERO DE FUNCIONARIOS                                                                                                     3694 non-null   object
#  21  GESTOR?                                                                                                                    3694 non-null   object
#  22  NIVEL                                                                                                                      2981 non-null   object
#  23  NOVO NIVEL                                                                                                                 3694 non-null   object
#  24  CARGO COMO GESTOR                                                                                                          713 non-null    object
#  25  CARGO ATUAL                                                                                                                2981 non-null   object
#  26  FAIXA SALARIAL                                                                                                             3694 non-null   object
#  27  QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?                                                                     3694 non-null   object
#  28  QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  3694 non-null   object
#  29  SALARIO                                                                                                                    3694 non-null   float64
# dtypes: bool(3), float64(2), object(25)
# memory usage: 913.6+ KB

# %% [markdown]
# ## TRABALHANDO COLUNA DE GENERO

# %%
dados.groupby('GENERO', dropna=False)['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %%
#SUBSTITUIR AS CELULAS NULAS POR UM TEXTO
dados['GENERO'] = dados['GENERO'].fillna("Prefiro não informar")

# %%
dados.groupby('GENERO', dropna=False)['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      21
# Name: ID, dtype: int64

# %% [markdown]
# ### TRABALHANDO COLUNA DE IDADE

# %%
dados['IDADE'].isnull().value_counts()
# Out:
# IDADE
# False    4197
# True       74
# Name: count, dtype: int64

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'PREJUDICA',
#        'ASPECTOS_PREJUDICADOS', 'VIVE_NO_BRASIL', 'ESTADO ONDE MORA',
#        'UF ONDE MORA', 'REGIAO ONDE MORA', 'MUDOU DE ESTADO?',
#        'REGIAO DE ORIGEM', 'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO', 'COMPUTAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'NIVEL', 'NOVO NIVEL',
#        'CARGO COMO GESTOR', 'CARGO ATUAL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# FAIXA IDADE
# 55+      68
# 17-21     6
# Name: count, dtype: int64

# %%
media_17_21 = dados[dados['FAIXA IDADE']=='17-21']['IDADE'].mean()

# %%
dados.loc[(dados['FAIXA IDADE']== '17-21')& (dados['IDADE'].isnull()), 'IDADE'] = media_17_21

# %%
dados[dados['FAIXA IDADE']=='55+']['IDADE']
# Out:
# 9      NaN
# 66     NaN
# 96     NaN
# 121    NaN
# 156    NaN
#         ..
# 4001   NaN
# 4043   NaN
# 4048   NaN
# 4061   NaN
# 4215   NaN
# Name: IDADE, Length: 68, dtype: float64

# %%
dados[dados['FAIXA IDADE']=='55+']['NIVEL']
# Out:
# 9        Pleno
# 66      Júnior
# 96       Pleno
# 121      Pleno
# 156     Júnior
#          ...
# 4001       NaN
# 4043       NaN
# 4048       NaN
# 4061       NaN
# 4215    Sênior
# Name: NIVEL, Length: 68, dtype: object

# %%
media_geral = dados['IDADE'].mean()
media_geral
# Out:
# np.float64(31.153517220250375)

# %%
dados.loc[(dados['FAIXA IDADE'] == '55+') & (dados['IDADE'].isnull()), 'IDADE'] = media_geral

# %% [markdown]
# ## TRATANDO A COLUNA SALARIO

# %%
dados['FAIXA SALARIAL'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4266    False
# 4267    False
# 4268    False
# 4269    False
# 4270    False
# Name: FAIXA SALARIAL, Length: 4271, dtype: bool

# %% [markdown]
# ### VALORES DISCREPANTES (OUTLIERS)

# %%
lista_idades2 = [26,30,32,22,26,35,400,20,43,31,23]

# %%
media = np.mean(lista_idades2)

# %%
#desvio padrao
desvio = np.std(lista_idades2)

# %%
media + 3*desvio
# Out:
# np.float64(383.2314444674207)

# %%
media - 3*desvio
# Out:
# np.float64(-258.1405353765116)

# %%
import matplotlib.pyplot as plt

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'PREJUDICA',
#        'ASPECTOS_PREJUDICADOS', 'VIVE_NO_BRASIL', 'ESTADO ONDE MORA',
#        'UF ONDE MORA', 'REGIAO ONDE MORA', 'MUDOU DE ESTADO?',
#        'REGIAO DE ORIGEM', 'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO', 'COMPUTAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'NIVEL', 'NOVO NIVEL',
#        'CARGO COMO GESTOR', 'CARGO ATUAL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
plt.boxplot(lista_idades2)
#
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7bccc751f710>,
#   <matplotlib.lines.Line2D at 0x7bccc751f050>],
#  'caps': [<matplotlib.lines.Line2D at 0x7bccc751f560>,
#   <matplotlib.lines.Line2D at 0x7bccc751e1b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7bcce6233dd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7bccc751da00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7bccc751cb90>],
#  'means': []}

# %%
plt.boxplot(dados['SALARIO'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7bccc778d1f0>,
#   <matplotlib.lines.Line2D at 0x7bccc778f0b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7bcccc192510>,
#   <matplotlib.lines.Line2D at 0x7bcccc1901d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7bccc778d7f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7bccc7721af0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7bccc77219a0>],
#  'means': []}

# %%
mediana_salario = dados['SALARIO'].median()
mediana_salario
# Out:
# 7000.0

# %%
dados.loc[dados['SALARIO'].isnull(), 'SALARIO'] = mediana_salario

# %%
Q1 = dados['SALARIO'].quantile(.25)
Q1
# Out:
# np.float64(5000.0)

# %%
Q3 = dados['SALARIO'].quantile(.75)
Q3
# Out:
# np.float64(10000.0)

# %%
IQR = Q3-Q1
IQR
# Out:
# np.float64(5000.0)

# %%
lim_superior = Q3 + (1.5*IQR)
lim_superior
# Out:
# np.float64(17500.0)

# %%
lim_inferior = Q1 + (1.5*IQR)
lim_inferior
# Out:
# np.float64(12500.0)

# %%
media_salario = dados['SALARIO'].mean()
media_salario
# Out:
# np.float64(9858.772652774525)

# %%
desvio_padrao = dados['SALARIO'].std()
desvio_padrao
# Out:
# 16447.820781518305

# %%
limite_superior = media_salario + (3*desvio_padrao)
limite_superior
# Out:
# np.float64(59202.23499732944)

# %%
dados[dados['SALARIO']>limite_superior]['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# de R$ 30.001/mês a R$ 40.000/mês    6
# Name: count, dtype: int64

# %%
media_30_40 = dados[(dados['FAIXA SALARIAL'] == 'de R$ 30.001/mês a R$ 40.000/mês') & (dados['SALARIO']<limite_superior)]['SALARIO'].mean()

# %%
dados.loc[(dados['FAIXA SALARIAL'] == 'de R$ 30.001/mês a R$ 40.000/mês') & (dados['SALARIO']>limite_superior), 'SALARIO'] = media_30_40

# %%
dados[dados['SALARIO']>limite_superior]['FAIXA SALARIAL'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
plt.boxplot(dados['SALARIO'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7bccc76c76b0>,
#   <matplotlib.lines.Line2D at 0x7bccc76c7ec0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7bccc7389df0>,
#   <matplotlib.lines.Line2D at 0x7bccc738be60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7bccc76c7380>],
#  'medians': [<matplotlib.lines.Line2D at 0x7bccc7389d00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7bccc7388080>],
#  'means': []}

# %% [markdown]
# ## DISTRIBUIÇÃO AMOSTRAL E INTERVALO DE CONFIANÇA

# %%
salarios = dados['SALARIO']
salarios
# Out:
# 0       10000.0
# 1        5000.0
# 2       14000.0
# 3       14000.0
# 4        7000.0
#          ...
# 4266     5000.0
# 4267     3500.0
# 4268    18000.0
# 4269     1000.0
# 4270     3500.0
# Name: SALARIO, Length: 4271, dtype: float64

# %%
media_amostral = np.mean(salarios)
media_amostral
# Out:
# np.float64(9347.342542730039)

# %%
desvio_amostral = np.std(salarios)
desvio_amostral
# Out:
# 7183.702960991913

# %%
nivel_confianca = 0.95

# %%
tamanho_amostra = len(salarios)
tamanho_amostra
# Out:
# 4271

# %%
from scipy import stats

# %%
erro_padrao = stats.sem(salarios)
erro_padrao
# Out:
# np.float64(109.93460716658748)

# %%
intervalo_confianca = stats.t.interval(nivel_confianca, tamanho_amostra-1, loc=media_amostral, scale=erro_padrao)
intervalo_confianca
# Out:
# (np.float64(9131.813578963694), np.float64(9562.871506496384))

# %% [markdown]
# ## FEATURING ENGINEERING

# %%
def preencher_nivel(gestor,nivel):
  if gestor == 1:
    return "Pessoa Gestora"
  else:
    return nivel

# %%
dados['NOVO NIVEL'] = dados.apply(lambda x: preencher_nivel(x['GESTOR?'], x['NIVEL']), axis=1)

# %%
dados['NOVO NIVEL'].value_counts()
# Out:
# NOVO NIVEL
# Pleno             1060
# Júnior            1023
# Sênior             898
# Pessoa Gestora     713
# Name: count, dtype: int64

# %%
dados['NIVEL']
# Out:
# 0       Júnior
# 1          NaN
# 2        Pleno
# 3       Sênior
# 4        Pleno
#          ...
# 4266     Pleno
# 4267     Pleno
# 4268       NaN
# 4269    Júnior
# 4270    Júnior
# Name: NIVEL, Length: 4271, dtype: object

# %%
dados = pd.get_dummies(dados, columns=['NIVEL'])

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'PREJUDICA',
#        'ASPECTOS_PREJUDICADOS', 'VIVE_NO_BRASIL', 'ESTADO ONDE MORA',
#        'UF ONDE MORA', 'REGIAO ONDE MORA', 'MUDOU DE ESTADO?',
#        'REGIAO DE ORIGEM', 'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO', 'COMPUTAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'NOVO NIVEL', 'CARGO COMO GESTOR',
#        'CARGO ATUAL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior'],
#       dtype='object')

# %%
def determinar_geracao(idade):
  if 39<idade<=58:
    return 'Geracao X'
  elif 29<idade<=39:
    return 'Millenial'
  elif 13<idade<=29:
    return 'Geracao X'
  else:
    return "Outra geracao"

# %%
dados['GERACAO'] = dados['IDADE'].apply(determinar_geracao)

# %%
dados['GERACAO'].value_counts()
# Out:
# GERACAO
# Geracao X    2510
# Millenial    1761
# Name: count, dtype: int64

# %%
dados2 = pd.read_excel("/content/drive/MyDrive/Curso Analise de Dados/Planilha_Aula_parte2.xlsx")

# %%
dados2.head()
# Out:
#                                  ID  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96
# 1  zzls2oftfn9law393oezzls2ofhvfpzd
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg
#
#   Quanto tempo de experiência na área de dados você tem?  \
# 0                                      de 1 a 2 anos
# 1                                      de 3 a 4 anos
# 2                                      de 3 a 4 anos
# 3                                      de 4 a 6 anos
# 4             Não tenho experiência na área de dados
#
#   Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?  \
# 0                                     de 7 a 10 anos
# 1                                     Menos de 1 ano
# 2                                    Mais de 10 anos
# 3  Não tive experiência na área de TI/Engenharia ...
# 4                                    Mais de 10 anos
#
#   Você está satisfeito na sua empresa atual?  \
# 0                                       True
# 1                                      False
# 2                                      False
# 3                                       True
# 4                                      False
#
#   Qual o principal motivo da sua insatisfação com a empresa atual?  \
# 0                                                NaN
# 1  Falta de oportunidade de crescimento no empreg...
# 2  Falta de oportunidade de crescimento no empreg...
# 3                                                NaN
# 4  Falta de oportunidade de crescimento no empreg...
#
#   Você participou de entrevistas de emprego nos últimos 6 meses?  \
# 0  Não participei de entrevistas de emprego/proce...
# 1          Sim, fiz entrevistas mas não fui aprovado
# 2  Não participei de entrevistas de emprego/proce...
# 3               Sim, fui aprovado e mudei de emprego
# 4  Não participei de entrevistas de emprego/proce...
#
#   Você pretende mudar de emprego nos próximos 6 meses?  \
# 0  Não estou buscando e não pretendo mudar de emp...
# 1  Estou em busca de oportunidades dentro ou fora...
# 2  Não estou buscando, mas me considero aberto a ...
# 3  Não estou buscando, mas me considero aberto a ...
# 4  Não estou buscando, mas me considero aberto a ...
#
#   Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?  \
# 0                                         Benefícios
# 1  Remuneração/Salário, Plano de carreira e oport...
# 2  Remuneração/Salário, Flexibilidade de trabalho...
# 3  Remuneração/Salário, Flexibilidade de trabalho...
# 4  Remuneração/Salário, Oportunidade de aprendiza...
#
#             Atualmente qual a sua forma de trabalho?  \
# 0                             Modelo 100% presencial
# 1                             Modelo 100% presencial
# 2  Modelo híbrido com dias fixos de trabalho pres...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
#
#            Qual a forma de trabalho ideal para você?  \
# 0  Modelo híbrido com dias fixos de trabalho pres...
# 1  Modelo híbrido flexível (o funcionário tem lib...
# 2  Modelo híbrido flexível (o funcionário tem lib...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
#
#   Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?  \
# 0   Vou aceitar e retornar ao modelo 100% presencial
# 1   Vou aceitar e retornar ao modelo 100% presencial
# 2  Vou procurar outra oportunidade no modelo híbr...
# 3  Vou procurar outra oportunidade no modelo híbr...
# 4   Vou aceitar e retornar ao modelo 100% presencial
#
#                Sua empresa passu por Layoff em 2022?  \
# 0  Não ocorreram layoffs/demissões em massa na em...
# 1  Não ocorreram layoffs/demissões em massa na em...
# 2  Não ocorreram layoffs/demissões em massa na em...
# 3  Não ocorreram layoffs/demissões em massa na em...
# 4  Não ocorreram layoffs/demissões em massa na em...
#
#                                              Atuacao  \
# 0                                Engenharia de Dados
# 1                                             Gestor
# 2   desenvolve modelos preditivos e algoritmos de...
# 3   desenvolve modelos preditivos e algoritmos de...
# 4                                      Outra atuação
#
#   Quais das linguagens listadas abaixo você utiliza no trabalho?
# 0                                                SQL
# 1                                                NaN
# 2                                                  1
# 3                                                  0
# 4                                                SQL

# %%
dados = dados.merge(dados2, on='ID', how='left')

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'PREJUDICA',
#        'ASPECTOS_PREJUDICADOS', 'VIVE_NO_BRASIL', 'ESTADO ONDE MORA',
#        'UF ONDE MORA', 'REGIAO ONDE MORA', 'MUDOU DE ESTADO?',
#        'REGIAO DE ORIGEM', 'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO', 'COMPUTAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'NOVO NIVEL', 'CARGO COMO GESTOR',
#        'CARGO ATUAL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior', 'GERACAO',
#        'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
#        'Você está satisfeito na sua empresa atual?',
#        'Qual o principal motivo da sua insatisfação com a empresa atual?',
#        'Você participou de entrevistas de emprego nos últimos 6 meses?',
#        'Você pretende mudar de emprego nos próximos 6 meses?',
#        'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?',
#        'Atualmente qual a sua forma de trabalho?',
#        'Qual a forma de trabalho ideal para você?',
#        'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?',
#        'Sua empresa passu por Layoff em 2022?', 'Atuacao',
#        'Quais das linguagens listadas abaixo você utiliza no trabalho?'],
#       dtype='object')

# %%
dados['Você pretende mudar de emprego nos próximos 6 meses?'].value_counts()
# Out:
# Você pretende mudar de emprego nos próximos 6 meses?
# Não estou buscando, mas me considero aberto a outras oportunidades         1354
# Estou em busca de oportunidades dentro ou fora do Brasil                   1011
# Não estou buscando e não pretendo mudar de emprego nos próximos 6 meses     978
# Estou em busca de oportunidades, mas apenas fora do Brasil                  353
# Name: count, dtype: int64

# %%
dados['EM_BUSCA'] = dados['Você pretende mudar de emprego nos próximos 6 meses?'].str.contains('em busca', case=False)

# %%
dados['EM_BUSCA'].value_counts()
# Out:
# EM_BUSCA
# False    2332
# True     1364
# Name: count, dtype: int64

# %%
dados['ABERTO_OPORTUNIDADES'] = dados['Você pretende mudar de emprego nos próximos 6 meses?'].str.contains('aberto', case=False)

# %%
dados['ABERTO_OPORTUNIDADES']
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 4268    False
# 4269    False
# 4270     True
# 4271    False
# 4272    False
# Name: ABERTO_OPORTUNIDADES, Length: 4273, dtype: object

# %%
dados['COR/RACA/ETNIA'].value_counts()
# Out:
# COR/RACA/ETNIA
# Branca                  2746
# Parda                   1054
# Preta                    291
# Amarela                  128
# Prefiro não informar      26
# Outra                     17
# Indígena                  11
# Name: count, dtype: int64

# %%
#criar nova tabela
dados["ETNIA"] = dados['COR/RACA/ETNIA']

# %%
#definindo a funcao
def categoria_etnia(ETNIA):
  if ETNIA == 'Branca':
    return 'Brancas'
  elif ETNIA == ['Parda', 'Preta', 'Amarela', 'Indígena']:
    return 'Nao Branca'
  else:
    return 'Outra'

# %%
dados['ETNIA'] = dados['COR/RACA/ETNIA'].apply(categoria_etnia)

# %%
dados['ETNIA'].value_counts()
# Out:
# ETNIA
# Brancas    2746
# Outra      1527
# Name: count, dtype: int64

# %% [markdown]
# ##CORRELAÇÃO

# %%
correlacao_continua = dados['IDADE'].corr(dados['SALARIO'])
correlacao_continua
# Out:
# np.float64(0.302150012326799)

# %%
from scipy.stats import chi2_contingency

# %%
def cramer_coeficiente(coluna1, coluna2):
  tabela_cruzada = np.array(pd.crosstab(coluna1,coluna2))
  chi2 = chi2_contingency(tabela_cruzada)[0]
  soma = np.sum(tabela_cruzada)
  mini = min(tabela_cruzada.shape)-1
  cramer = np.sqrt(chi2/(soma*mini))
  return cramer

# %%
cramer_coeficiente(dados['COR/RACA/ETNIA'], dados['NIVEL DE ENSINO'])
# Out:
# np.float64(0.04499106580480143)

# %%
tabela_cruzada = pd.crosstab(dados['COR/RACA/ETNIA'], dados['NIVEL DE ENSINO'])
tabela_cruzada
# Out:
# NIVEL DE ENSINO       Doutorado ou Phd  Estudante de Graduação  \
# COR/RACA/ETNIA
# Amarela                              7                      15
# Branca                             127                     365
# Indígena                             0                       2
# Outra                                0                       0
# Parda                               50                     178
# Prefiro não informar                 1                       2
# Preta                                6                      51
#
# NIVEL DE ENSINO       Graduação/Bacharelado  Mestrado  \
# COR/RACA/ETNIA
# Amarela                                  50        14
# Branca                                  999       355
# Indígena                                  4         2
# Outra                                     6         3
# Parda                                   333       113
# Prefiro não informar                     14         1
# Preta                                   104        33
#
# NIVEL DE ENSINO       Não tenho graduação formal  Prefiro não informar  \
# COR/RACA/ETNIA
# Amarela                                        2                     0
# Branca                                        65                     8
# Indígena                                       0                     0
# Outra                                          1                     0
# Parda                                         33                     3
# Prefiro não informar                           0                     1
# Preta                                          9                     0
#
# NIVEL DE ENSINO       Pós-graduação
# COR/RACA/ETNIA
# Amarela                          40
# Branca                          827
# Indígena                          3
# Outra                             7
# Parda                           344
# Prefiro não informar              7
# Preta                            88

# %%
np.array(tabela_cruzada)
# Out:
# array([[  7,  15,  50,  14,   2,   0,  40],
#        [127, 365, 999, 355,  65,   8, 827],
#        [  0,   2,   4,   2,   0,   0,   3],
#        [  0,   0,   6,   3,   1,   0,   7],
#        [ 50, 178, 333, 113,  33,   3, 344],
#        [  1,   2,  14,   1,   0,   1,   7],
#        [  6,  51, 104,  33,   9,   0,  88]])

# %% [markdown]
# #Exercicio

# %%
tabela_cruzada2 = pd.crosstab(dados['NIVEL DE ENSINO'], dados['GENERO'])
cramer_coeficiente(dados['NIVEL DE ENSINO'], dados['GENERO'])
# Out:
# np.float64(0.076119232802818)

# %% [markdown]
# #CONECTANDO SQL COM PANDAS

# %%
import sqlite3

# %%
conexao = sqlite3.connect('/content/drive/MyDrive/Curso Analise de Dados/status_brasil')

# %%
query = "SELECT * FROM Municipios_Brasileiros WHERE Cidade LIKE 'Itaquaquecetuba'"

# %%
import pandas as pd
pd.read_sql(query, con = conexao)
# Out:
#             Cidade Estado   Regiao  municipio_ID
# 0  Itaquaquecetuba     SP  Sudeste          5043

# %%
query = '''SELECT Municipios_Brasileiros.Estado,AVG( Municipio_Status.renda)
FROM Municipios_Brasileiros
INNER JOIN Municipio_Status ON Municipios_Brasileiros.municipio_ID = Municipio_Status.municipio_ID
GROUP BY Municipios_Brasileiros.Estado'''

# %%
pd.read_sql(query, con = conexao)
# Out:
#    Estado  AVG( Municipio_Status.renda)
# 0      AC                      0.585455
# 1      AL                      0.548363
# 2      AM                      0.545113
# 3      AP                      0.618875
# 4      BA                      0.574805
# 5      CE                      0.559293
# 6      DF                      0.863000
# 7      ES                      0.680628
# 8      GO                      0.683980
# 9      MA                      0.531664
# 10     MG                      0.652008
# 11     MS                      0.687846
# 12     MT                      0.682149
# 13     PA                      0.572357
# 14     PB                      0.564423
# 15     PE                      0.574378
# 16     PI                      0.546813
# 17     PR                      0.691915
# 18     RJ                      0.704796
# 19     RN                      0.580183
# 20     RO                      0.658173
# 21     RR                      0.577867
# 22     RS                      0.722115
# 23     SC                      0.728038
# 24     SE                      0.577147
# 25     SP                      0.716571
# 26     TO                      0.610543

# %%
dados = pd.read_excel('/content/drive/MyDrive/Curso Analise de Dados/planilha_modulo3.xlsx')

# %%
lista_estados = list(dados['UF ONDE MORA'].unique())

# %%
query = '''SELECT Municipios_Brasileiros.Estado,AVG( Municipio_Status.renda)
FROM Municipios_Brasileiros
INNER JOIN Municipio_Status ON Municipios_Brasileiros.municipio_ID = Municipio_Status.municipio_ID
WHERE Municipios_Brasileiros.Estado IN ({})
GROUP BY Municipios_Brasileiros.Estado'''.format(','.join(['?' for _ in lista_estados]))

# %%
pd.read_sql(query, con = conexao, params=lista_estados)
# Out:
#    Estado  AVG( Municipio_Status.renda)
# 0      AL                      0.548363
# 1      AM                      0.545113
# 2      BA                      0.574805
# 3      CE                      0.559293
# 4      DF                      0.863000
# 5      ES                      0.680628
# 6      GO                      0.683980
# 7      MA                      0.531664
# 8      MG                      0.652008
# 9      MS                      0.687846
# 10     MT                      0.682149
# 11     PA                      0.572357
# 12     PB                      0.564423
# 13     PE                      0.574378
# 14     PI                      0.546813
# 15     PR                      0.691915
# 16     RJ                      0.704796
# 17     RN                      0.580183
# 18     RS                      0.722115
# 19     SC                      0.728038
# 20     SE                      0.577147
# 21     SP                      0.716571

# %%
a = ['batata','tomate', 'alface']

# %%
print('eu gosto de {},{},{}'.format(a[0],a[1], a[2]))
# Out:
# eu gosto de batata,tomate,alface

# %%
print('eu gosto de {}'.format(','.join(a)))
# Out:
# eu gosto de batata,tomate,alface

# %%
print(query)
# Out:
# SELECT Municipios_Brasileiros.Estado,AVG( Municipio_Status.renda)
# FROM Municipios_Brasileiros
# INNER JOIN Municipio_Status ON Municipios_Brasileiros.municipio_ID = Municipio_Status.municipio_ID
# WHERE Municipios_Brasileiros.Estado IN (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)
# GROUP BY Municipios_Brasileiros.Estado

# %%
estados_renda = pd.read_sql(query, con = conexao, params=lista_estados)

# %%
dados.rename(columns={'UF ONDE MORA':'Estado'}, inplace=True)

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'Estado', 'REGIAO ONDE MORA',
#        'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM', 'NIVEL DE ENSINO',
#        'ÁREA DE FORMAÇÃO', 'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
dados = dados.merge(estados_renda, on='Estado', how='left')

# %%
correlacao_renda_salario = dados['SALARIO'].corr(dados['AVG( Municipio_Status.renda)'])
correlacao_renda_salario
# Out:
# np.float64(0.07248950401807613)

# %% [markdown]
# ## visualizacao de dados

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dados = pd.read_excel('/content/drive/MyDrive/Curso Analise de Dados/planilha_modulo3.xlsx')

# %%
dados.head()
# Out:
#                                  ID  IDADE FAIXA IDADE     GENERO  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
#
#                           ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 0                                           NaN            True
# 1  Aprovação em processos seletivos/entrevistas            True
# 2                                           NaN            True
# 3                                           NaN            True
# 4                                           NaN            True
#
#         ESTADO ONDE MORA  ...  \
# 0  Distrito Federal (DF)  ...
# 1              Pará (PA)  ...
# 2  Distrito Federal (DF)  ...
# 3      Minas Gerais (MG)  ...
# 4              Pará (PA)  ...
#
#   Você pretende mudar de emprego nos próximos 6 meses?  \
# 0  Não estou buscando e não pretendo mudar de emp...
# 1  Estou em busca de oportunidades dentro ou fora...
# 2  Não estou buscando, mas me considero aberto a ...
# 3  Não estou buscando, mas me considero aberto a ...
# 4  Não estou buscando, mas me considero aberto a ...
#
#   Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?  \
# 0                                         Benefícios
# 1  Remuneração/Salário, Plano de carreira e oport...
# 2  Remuneração/Salário, Flexibilidade de trabalho...
# 3  Remuneração/Salário, Flexibilidade de trabalho...
# 4  Remuneração/Salário, Oportunidade de aprendiza...
#
#             Atualmente qual a sua forma de trabalho?  \
# 0                             Modelo 100% presencial
# 1                             Modelo 100% presencial
# 2  Modelo híbrido com dias fixos de trabalho pres...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
#
#            Qual a forma de trabalho ideal para você?  \
# 0  Modelo híbrido com dias fixos de trabalho pres...
# 1  Modelo híbrido flexível (o funcionário tem lib...
# 2  Modelo híbrido flexível (o funcionário tem lib...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
#
#   Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?  \
# 0   Vou aceitar e retornar ao modelo 100% presencial
# 1   Vou aceitar e retornar ao modelo 100% presencial
# 2  Vou procurar outra oportunidade no modelo híbr...
# 3  Vou procurar outra oportunidade no modelo híbr...
# 4   Vou aceitar e retornar ao modelo 100% presencial
#
#                Sua empresa passu por Layoff em 2022?  \
# 0  Não ocorreram layoffs/demissões em massa na em...
# 1  Não ocorreram layoffs/demissões em massa na em...
# 2  Não ocorreram layoffs/demissões em massa na em...
# 3  Não ocorreram layoffs/demissões em massa na em...
# 4  Não ocorreram layoffs/demissões em massa na em...
#
#                                              Atuacao  \
# 0                                Engenharia de Dados
# 1                                             Gestor
# 2  desenvolve modelos preditivos e algoritmos de ...
# 3  desenvolve modelos preditivos e algoritmos de ...
# 4                                      Outra atuação
#
#   Quais das linguagens listadas abaixo você utiliza no trabalho? EM_BUSCA  \
# 0                                                SQL                  0.0
# 1                                                NaN                  1.0
# 2                                                  1                  0.0
# 3                                                  0                  0.0
# 4                                                SQL                  0.0
#
#    ABERTO_OPORTUNIDADES
# 0                   0.0
# 1                   0.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
#
# [5 rows x 46 columns]

# %%
dados['GENERO']
# Out:
# 0       Masculino
# 1       Masculino
# 2       Masculino
# 3       Masculino
# 4        Feminino
#           ...
# 4266    Masculino
# 4267     Feminino
# 4268    Masculino
# 4269    Masculino
# 4270    Masculino
# Name: GENERO, Length: 4271, dtype: object

# %%
genero_counts = dados['GENERO'].value_counts()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.bar(height= genero_counts.values, x = genero_counts.index)
plt.title('Distribuicao de Generos')
plt.xlabel('Genero')
plt.ylabel('Quantidade')
plt.show()

# %%
import seaborn as sns

# %%
plt.figure()
sns.countplot(data=dados, x='GENERO', palette='pastel')
plt.title('Distribuicao de Generos')
plt.xlabel('Genero')
plt.ylabel('Quantidade')
plt.grid(True)
plt.show()
#
# Out:
# /tmp/ipykernel_16036/4248284228.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=dados, x='GENERO', palette='pastel')

# %%
salario_idade = dados.groupby('IDADE')['SALARIO'].mean()
salario_idade
# Out:
# IDADE
# 18.0     1320.142857
# 19.0     3354.875000
# 20.0     3072.842105
# 21.0     3729.639344
# 22.0     3791.131868
# 23.0     5278.712000
# 24.0     5885.259036
# 25.0     7614.970464
# 26.0     7709.654618
# 27.0     8308.212687
# 28.0     9998.934363
# 29.0    11576.009050
# 30.0    12300.294931
# 31.0    12361.170404
# 32.0    11209.569307
# 33.0    12264.798742
# 34.0    12909.736527
# 35.0    15967.629032
# 36.0    16185.223881
# 37.0    13455.971429
# 38.0    20761.608696
# 39.0    14741.202247
# 40.0    17245.571429
# 41.0    14323.053571
# 42.0    12994.047619
# 43.0    15922.772727
# 44.0    15695.435897
# 45.0    17884.432432
# 46.0    12549.000000
# 47.0    11970.769231
# 48.0    12736.473684
# 49.0    14194.333333
# 50.0    17022.129032
# 51.0     9316.000000
# 52.0    13164.133333
# 53.0    10962.250000
# 54.0    18198.222222
# Name: SALARIO, dtype: float64

# %%
plt.figure()
plt.plot(salario_idade.index, salario_idade.values, marker='o', linestyle = '-')
plt.title('Salario x Idade')
plt.xlabel('Idade')
plt.ylabel('Salario')
plt.grid(True)
plt.show()
#

# %%
import plotly.express as px

# %%
fig = px.line(salario_idade.reset_index(), x='IDADE', y='SALARIO', title='Salario x Idade', markers = True)
fig.show()
#
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c2da874b-153e-4e96-b5f4-59075c0f952e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2da874b-153e-4e96-b5f4-59075c0f952e")) {                    Plotly.newPlot(                        "c2da874b-153e-4e96-b5f4-59075c0f952e",                        [{"hovertemplate":"IDADE=%{x}\u003cbr\u003eSALARIO=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[18.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0,30.0,31.0,32.0,33.0,34.0,35.0,36.0,37.0,38.0,39.0,40.0,41.0,42.0,43.0,44.0,45.0,46.0,47.0,48.0,49.0,50.0,51.0,52.0,53.0,54.0],"xaxis":"x","y":[1320.142857142857,3354.875,3072.842105263158,3729.6393442622953,3791.131868131868,5278.712,5885.259036144578,7614.970464135021,7709.654618473895,8308.212686567163,9998.934362934362,11576.009049773756,12300.294930875576,12361.170403587445,11209.569306930693,12264.798742138364,12909.736526946108,15967.629032258064,16185.223880597016,13455.971428571429,20761.608695652172,14741.202247191011,17245.571428571428,14323.05357142857,12994.047619047618,15922.772727272728,15695.435897435897,17884.432432432433,12549.0,11970.76923076923,12736.473684210527,14194.333333333334,17022.129032258064,9316.0,13164.133333333333,10962.25,18198.222222222223],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0 ...

# %%
plt.figure()
plt.scatter(x=dados['IDADE'], y=dados['SALARIO'], alpha = 0.5)
plt.title('Salario x Idade')
plt.xlabel('Idade')
plt.ylabel('Salario')
plt.grid(True)
plt.show()
#

# %%
fig = px.scatter(dados, x='IDADE', y='SALARIO', title='Salario x Idade', opacity=0.5)
fig.show()
#
#
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="889925da-810b-49b1-8538-7df882876cd5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("889925da-810b-49b1-8538-7df882876cd5")) {                    Plotly.newPlot(                        "889925da-810b-49b1-8538-7df882876cd5",                        [{"hovertemplate":"IDADE=%{x}\u003cbr\u003eSALARIO=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.5,"symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[39.0,32.0,53.0,27.0,46.0,32.0,21.0,31.0,33.0,null,25.0,33.0,31.0,24.0,35.0,28.0,31.0,29.0,28.0,26.0,37.0,33.0,26.0,46.0,34.0,27.0,25.0,27.0,24.0,25.0,26.0,27.0,29.0,33.0,24.0,25.0,27.0,26.0,31.0,32.0,40.0,29.0,35.0,32.0,18.0,29.0,24.0,24.0,46.0,29.0,30.0,37.0,28.0,40.0,28.0,30.0,34.0,33.0,28.0,34.0,31.0,30.0,39.0,26.0,39.0,31.0,null,38.0,48.0,28.0,27.0,26.0,33.0,28.0,39.0,31.0,25.0,43.0,35.0,44.0,31.0,43.0,34.0,32.0,48.0,29.0,33.0,33.0,26.0,50.0,28.0,22.0,31.0,37.0,30.0,36.0,null,40.0,51.0,27.0,29.0,32.0,29.0,24.0,31.0,26.0,31.0,44.0,28.0,33.0,39.0,25.0,28.0,31.0,20.0,25.0,24.0,30.0,27.0,26.0,22.0,null,32.0,37.0,31.0,27.0,31.0,27.0,33.0,23.0,22.0,42.0,25.0,26.0,34.0,36.0,21.0,29.0,29.0,27.0,25.0,30.0,25.0,29.0,24.0,24.0,31.0,36.0,31.0,33.0,47.0,22.0,26.0,26.0,39.0,30.0,null,31.0,41.0,37.0,26.0,32.0,null,28.0,24.0,32.0,34.0,44.0,26.0,31.0,34.0,41.0,31.0,39.0,29.0,36.0,22.0,28.0,29.0,31.0,26.0,32.0,25.0,33.0,33.0,29.0,25.0,33.0,24.0,34.0,32.0,46.0,34.0,42.0,21.0,32.0,36.0,39.0,41.0,31.0,35.0,29.0,26.0,24.0,29.0,21.0,33.0,29.0,30.0,32.0,26.0,34.0,34.0,20.0,22.0,45.0,24.0,26.0,26.0,27.0,34.0,31.0,50.0,27.0,34.0,23.0,45.0,33.0,21.0,30.0,26.0,35.0,27.0,31.0,30.0,40.0,24.0,32.0,31.0,34.0,22.0,29.0,36.0,44.0,22.0,29.0,18.0,30.0,28.0,26.0,27.0,24.0,31.0,24.0,31.0,33.0,21.0,30.0,30.0,33.0,34.0,27.0,26.0,28.0,31.0,33.0,37.0,28.0,50.0,31.0,25.0,30.0,33.0,36.0,null,22.0,25.0,42.0,27.0,26.0,30.0,24.0,29.0,26.0,29.0,37.0,31.0,29.0,25.0,27.0,29.0,42.0,32.0,45.0,38.0,41.0,26.0,null,28.0,23.0,25.0,38.0,32.0,35.0,24.0,25.0,32.0,33.0,24.0,28.0,24.0,31.0,34.0,38.0,43.0,50.0,22.0,33.0,26.0,28.0,38.0,45.0,32.0,22.0,30.0,31.0,31.0,34.0,25.0,32.0,35.0,36.0,34.0,36.0,35.0,54.0,37.0,44.0,40.0,25.0,23.0,38.0,31.0,29.0,38.0,41.0,32.0,30.0,22.0,26.0,25.0,32.0,29.0,32.0,41.0,25.0,28.0,25.0,37.0,35.0,29.0,22.0,25.0,32.0,35.0,29.0,34.0,31.0,45.0,34.0,27.0,25.0,26.0,23.0,26.0,49.0,49.0,37.0,35.0,37.0,39.0,21.0,32.0,46.0,null,26.0,41.0,45.0,32.0,36.0,26.0,22.0,28.0,29.0,35.0,25.0,32.0,48.0,33.0,35.0,27.0,37.0,32.0,38.0,54.0,39.0,43.0,35.0,31.0,23.0,41.0,23.0,37.0,54.0,31.0,29.0,27.0,35.0,22.0,20.0,45.0,33.0,39.0,27.0,28.0,null,26.0,null,26.0,27.0,27.0,49.0,52.0,34.0,40.0,32.0,28.0,39.0,33.0,47.0,46.0,25.0,26.0,45.0,22.0,31.0,44.0,27.0,30.0,37.0,29.0,20.0,26.0,37.0,18.0,30.0,29.0,37.0,32.0,27.0,37.0,27.0,42.0,32.0,28.0,28.0,29.0,29.0,39.0,22.0,30.0,30.0,32.0,30.0,29.0,28.0,42.0,null,29.0,35.0,35.0,28.0,27.0,26.0,22.0,32.0,31.0,26.0,32.0,38.0,31.0,34.0,43.0,24.0,22.0,29.0,32.0,39.0,34.0,26.0,28.0,34.0,29.0,23.0,31.0,26.0,29.0,52.0,22.0,29.0,30.0,24.0,21.0,44.0,39.0,25.0,26.0,23.0,30.0,40.0,21.0,34.0,31.0,25.0,30.0,44.0,30.0,30.0,36.0,39.0,28.0,34.0,39.0,27.0,33.0,34.0,37.0,23.0,29.0,32.0,24.0,35.0,23.0,25.0,36.0,36.0,28.0,29.0,31.0,26.0,36.0,27.0,32.0,31.0,31.0,41.0,31.0,27.0,32.0,27.0,23.0,31.0,29.0,32.0,25.0,31.0,25.0,37.0,32.0,23.0,25.0,52.0,30.0,29.0,23.0,29.0,null,27.0,51.0,46.0,31.0,35.0,25.0,36.0,33.0,25.0,19.0,43.0,24.0,23.0,43.0,36.0,30.0,38.0,36.0,25.0,24.0,22.0,44.0,48.0,37.0,48.0,33.0,40.0,34.0,28.0,25.0,26.0,32.0,54.0,43.0,32.0,29.0,36.0,35.0,34.0,34.0,21.0,25.0,23.0,20.0,49.0,30.0,27.0,36.0,28.0,26.0,24.0,36.0,32.0,28.0,34.0,44.0,43.0,36.0,30.0,42.0,31.0,27.0,39.0,37.0,39.0,2 ...

# %% [markdown]
# ##EXERCICIO MODULO 6

# %%
dados_ex = pd.read_excel('/content/drive/MyDrive/Curso Analise de Dados/Cópia de municipios_brasileiro.xlsx')

# %%
dados_ex.columns
# Out:
# Index(['CITY', 'STATE', 'Pop_residente', 'IDHM_Rank', 'Renda', 'Educacao',
#        'CARRO', 'Regiao', ' ', ' .1'],
#       dtype='object')

# %%
regiao_renda = dados_ex.groupby('Regiao')['Renda'].mean()

# %%
plt.figure()
plt.plot(regiao_renda.index, regiao_renda.values, marker='o', linestyle = '-')
plt.title('Regiao x Renda')
plt.xlabel('IRegiao')
plt.ylabel('Renda')
plt.grid(True)
plt.show()
#
